# %% [markdown]
#
#  ## <font color="1497d4">  **Statistical Analysis for Accented Speech recognition**</font>
#
#
#
# <font color=white> **Mozilla Common Voice 10.0. dataset**</font>
#
# ## <font color="1497d4">  **Analyze results from Carlos’ model**</font>
#
# <font color=white> **Setup dev environment:**</font>

# %% [markdown]
# ###<font color="1497d4"> Import the necessary python libraries:</font>
#
#
# The next step is to import the required python libraries:
# *   NumPy:   for scientific computing.
# *   Matplotlib: a plotting library for Python.
# *   Matplotlib.pyplot:  a group of functions that allow matplotlib to work like MATLAB.
# *   Pandas: used for data science/data analysis.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Import math Library   -- # Check whether some values are NaN
import math

# %% [markdown]
# ###<font color="1497d4"> Importing the Dataset:</font>
#
#
# The next step is to import the dataset file by either uploading the file on Google Colab or mounting the google drive and empowering Colab to access all files(dataset)on it. Then to copy the dataset to our colab runtime files.

# %%
# Import the dataset file by method1 
# from google.colab import files
# uploaded = files.upload()

! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/results.json   /content/results.json

# copy the expermintations files to deal with them
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_at.txt /content/test_at.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_ca.txt /content/test_ca.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_ch.txt /content/test_ch.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_de_al.txt /content/test_de_al.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_de_ni.txt /content/test_de_ni.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_de.txt /content/test_de.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_fr.txt /content/test_fr.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_gb.txt /content/test_gb.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_it.txt /content/test_it.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_ru.txt /content/test_ru.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_us.txt /content/test_us.txt

# copy the expermintations files from Mozilla Commen Voice v 10 to deal with them

! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/cv-corpus04072022/de/validated.tsv /content/validated.tsv

# %% [markdown]
# ###<font color="1497d4"> Reading the Dataset:</font>
# **The following Method takes the dataset filename and loads it into data frame called dataset.**

# %%
#read a TSV file/Dataset

import pandas as pd
dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t')
dataset_validated_tsv
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                 client_id  \
# 0       0052c07533a6976233ad5926d950b523002c4d8cdd9ae8...
# 1       00aa59ff387a07bf1c056cccd6715b3c764201f51092c3...
# 2       02274179aeff73e1e7897ed6fec2355af2cd6e5410e3c6...
# 3       02650022b4a4266846057d97ae4d81da8af9e09e2a4bb1...
# 4       02786062ec85038ffeed4c38ed7b31d3aa8e6439817fb1...
# ...                                                   ...
# 793063  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 793064  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 793065  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 793066  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 793067  372293e65cdab88771e028a4351651ab2eff64438ddafc...
#
#                                 path  \
# 0       common_voice_de_17922420.mp3
# 1       common_voice_de_27060918.mp3
# 2       common_voice_de_19728810.mp3
# 3       common_voice_de_19156087.mp3
# 4       common_voice_de_27395829.mp3
# ...                              ...
# 793063  common_voice_de_32911655.mp3
# 793064  common_voice_de_32911638.mp3
# 793065  common_voice_de_32911641.mp3
# 793066  common_voice_de_32911661.mp3
# 793067  common_voice_de_32911666.mp3
#
#                                                  sentence  up_votes  \
# 0                Zieht euch bitte draußen die Schuhe aus.         2
# 1                     Es gibt auch mehrere Campingplätze.         2
# 2                        Es kommt zum Showdown in Gstaad.         2
# 3       Ihre Fotostrecken erschienen in Modemagazinen ...         3
# 4       Aber weißt du, wer den Stein wirklich ins Roll...         2
# ...                                                   ...       ...
# 793063  Gegen Bezahlung posierte sie für Fotos und gab...         3
# 793064  Zur Folgesaison wechselte er fest in die Niede...         6
# 793065  Er ist auf die Stile Schmetterling und Lagen s...         3
# 793066                           Vieles wurde exportiert.         6
# 793067   Bei Punktgleichheit zählt der direkte Vergleich.         3
#
#         down_votes      age gender  \
# 0                0      NaN    NaN
# 1                0      NaN    NaN
# 2                1      NaN    NaN
# 3                1      NaN    NaN
# 4                0      NaN    NaN
# ...            ...      ...    ...
# 793063           0  fifties   male
# 793064           0  fifties   male
# 793065           0  fifties   male
# 793066           0  fifties   male
# 793067           0  fifties   male
#
#                                                   accents locale segment
# 0                                                     NaN     de     NaN
# 1                                                     NaN     de     NaN
# 2                                                     NaN     de     NaN
# 3                                                     NaN     de     NaN
# 4                                                     NaN     de     NaN
# ...                                                   ...    ...     ...
# 793063  Nordrhein-Westfalen,Bundesdeutsch, Hochdeutsch...     de     NaN
# 793064  Nordrhein-Westfalen,Bundesdeutsch, Hochdeutsch...     de     NaN
# 793065  Nordrhein-Westfalen,Bundesdeutsch, Hochdeutsch...     de     NaN
# 793066  Nordrhein-Westfalen,Bundesdeutsch, Hochdeutsch...     de     NaN
# 793067  Nordrhein-Westfalen,Bundesdeutsch, Hochdeutsch...     de     NaN
#
# [793068 rows x 10 columns]

# %% [markdown]
# ###<font color="1497d4">The descriptive statistics and computational methods discussed in the data structure overview are all written to account for missing data. </font>
# **For example:**
# *   When countming data, NA (missing) values will be treated as zero.
# *   If the data are all NA, the result will be 0.
# *   Cumulative methods like cumcount() and cumprod() ignore NA values by default, but preserve them in the resulting arrays. To override this behaviour and include NA values, use skipna=False.
#
# http://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html#experimental-na-scalar-to-denote-missing-values

# %% [markdown]
# ###<font color="1497d4"> Cleaning our dataset</font>
#
# We have 49230  rows in our dataset. Consequently, we will delete the rows which do not meet the conditions (Values range). otherwise it changed normaly with the mean of the field in the small dataset.
# After deleting the rows which have missing data. We relize that the new number 4495 rows.

# %% [markdown]
# ###<font color="1497d4"> **You can find the test data, split by accent, in the data zip. The results are also within that zip file, named results.json. Here are some numbers and plots that we would like to have.**</font>
#
# 1.   **Duration distribution of audiofiles per speaker's accent, gender and age group, both as a plot and in terms of mean and variance.**
# 2.   **WER distribution per speaker's accent, gender, age group
# and duration, both as a plot and in terms of mean and variance.**

# %% [markdown]
# #### **Duration distribution of audiofiles per speaker's accent ,both as a plot and in terms of mean and variance.**

# %%
#################################Extract and calculate the duration_numeric########################################
# add Columns Names to the Dataset: header=None, names=['audio_filepath','text','duration']
dataset_test_at = pd.read_csv('test_at.txt', header=None, names=['audio_filepath','text','duration'])
'''
df['Numbers Only'] = df['Numbers and Text'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
'''
# extract the numeric values of the durations from the third Column and store it in a new column called
dataset_test_at['duration_numeric'] = dataset_test_at['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_at['duration_numeric'] =dataset_test_at['duration_numeric'].div(10)
# extract the numeric values of the durations from the third Column and store it in a new column called 
#dataset_test_at['audio_filepath_numeric'] = dataset_test_at['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_at['audio_filepath_numeric'] = dataset_test_at['audio_filepath'].str[-13:-5]

###dataset_test_at['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
dataset_test_at
# Out:
#                                          audio_filepath  \
# 0     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ...                                                 ...
# 4490  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4491  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4492  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4493  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4494  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                    text            duration  \
# 0      "text": "er ist nach eustache de saint pierre...    "duration": 4.9}
# 1      "text": "eine erste kleinformatige vorstudie ...   "duration": 10.1}
# 2      "text": "er blieb ohne erfolg und lag in st\u...    "duration": 9.0}
# 3      "text": "mein garten ist teil eines kleingart...    "duration": 3.7}
# 4      "text": "was habe ich damals f\u00fcr einen u...    "duration": 3.6}
# ...                                                 ...                 ...
# 4490   "text": "es handelt sich heute um eine wohnst...    "duration": 5.8}
# 4491   "text": "wir m\u00fcssen sie blo\u00df verbes...    "duration": 4.2}
# 4492   "text": "unter abspaltung von wasser bildet s...    "duration": 6.8}
# 4493   "text": "die sammlung wurde von gro\u00dfherz...    "duration": 5.6}
# 4494   "text": "w\u00e4hrend der zeit des dritten re...    "duration": 6.8}
#
#       duration_numeric audio_filepath_numeric
# 0                  4.9               31449916
# 1                 10.1               19730674
# 2                  9.0               19703888
# 3                  3.7               18507972
# 4                  3.6               24131267
# ...                ...                    ...
# 4490               5.8               23706817
# 4491               4.2               21599214
# 4492               6.8               25132532
# 4493               5.6               23778312
# 4494               6.8               23358245
#
# [4495 rows x 5 columns]

# %% [markdown]
# #### **Duration distribution of audiofiles per speaker's accent AT,CA, CH, DE_AL, DE_ni, DE, FR, GB, IT, RU, US. both as a plot and in terms of mean and variance.**

# %%
# copy the expermintations files to deal with them
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_at.txt /content/test_at.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_ca.txt /content/test_ca.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_ch.txt /content/test_ch.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_de_al.txt /content/test_de_al.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_de_ni.txt /content/test_de_ni.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_de.txt /content/test_de.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_fr.txt /content/test_fr.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_gb.txt /content/test_gb.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_it.txt /content/test_it.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_ru.txt /content/test_ru.txt
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/test_us.txt /content/test_us.txt

# %%
# Duration distribution of audiofiles per speaker's accent AT,CA, CH, DE_AL, DE_ni, DE, FR, GB, IT, RU, US. both as a plot and in terms of mean and variance.
import re # import the library of research about special value in String 
################################## Accent AT ###########################################
print('################################## Accent AT ###########################################')
# add Columns Names to the Dataset: header=None, names=['audio_filepath','text','duration']
dataset_test_at = pd.read_csv('test_at.txt', header=None, names=['audio_filepath','text','duration'])

'''
df['Numbers Only'] = df['Numbers and Text'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
'''

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_at['duration_numeric'] = dataset_test_at['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_at['duration_numeric'] =dataset_test_at['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_at['audio_filepath_numeric'] = dataset_test_at['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_at['audio_filepath_numeric'] = dataset_test_at['audio_filepath'].str[-13:-5]

##dataset_test_at['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_at)
################################### Accent CA ##########################################
print('################################## Accent CA ###########################################')
dataset_test_ca = pd.read_csv('test_ca.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_ca['duration_numeric'] = dataset_test_ca['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_ca['duration_numeric'] =dataset_test_ca['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].str[-13:-5]

print(dataset_test_ca)
##################################### Accent CH ########################################
print('################################## Accent CH ###########################################')
dataset_test_ch = pd.read_csv('test_ch.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_ch['duration_numeric'] = dataset_test_ch['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_ch['duration_numeric'] =dataset_test_ch['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_ch['audio_filepath_numeric'] = dataset_test_ch['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_ch['audio_filepath_numeric'] = dataset_test_ch['audio_filepath'].str[-13:-5]

print(dataset_test_ch)
##################################### Accent DE_AL ########################################
print('################################## Accent DE_AL ###########################################')
dataset_test_de_al = pd.read_csv('test_de_al.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_de_al['duration_numeric'] = dataset_test_de_al['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_de_al['duration_numeric'] =dataset_test_de_al['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_de_al['audio_filepath_numeric'] = dataset_test_de_al['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_de_al['audio_filepath_numeric'] = dataset_test_de_al['audio_filepath'].str[-13:-5]

print(dataset_test_de_al)
##################################### Accent DE_NI ########################################
print('################################## Accent DE_NI ###########################################')
dataset_test_de_ni = pd.read_csv('test_de_ni.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_de_ni['duration_numeric'] = dataset_test_de_ni['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_de_ni['duration_numeric'] =dataset_test_de_ni['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_de_ni['audio_filepath_numeric'] = dataset_test_de_ni['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_de_ni['audio_filepath_numeric'] = dataset_test_de_ni['audio_filepath'].str[-13:-5]

###dataset_test_de_ni['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_de_ni)
##################################### Accent DE ########################################
print('################################## Accent DE ###########################################')
dataset_test_de = pd.read_csv('test_de.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_de['duration_numeric'] = dataset_test_de['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_de['duration_numeric'] =dataset_test_de['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_de['audio_filepath_numeric'] = dataset_test_de['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_de['audio_filepath_numeric'] = dataset_test_de['audio_filepath'].str[-13:-5]

###dataset_test_de['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_de)
##################################### Accent FR ########################################
print('################################## Accent FR ###########################################')
dataset_test_fr = pd.read_csv('test_fr.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_fr['duration_numeric'] = dataset_test_fr['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_fr['duration_numeric'] =dataset_test_fr['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_fr['audio_filepath_numeric'] = dataset_test_fr['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_fr['audio_filepath_numeric'] = dataset_test_fr['audio_filepath'].str[-13:-5]

###dataset_test_fr['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_fr)
##################################### Accent GB ########################################
print('################################## Accent GB ###########################################')
dataset_test_gb = pd.read_csv('test_gb.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_gb['duration_numeric'] = dataset_test_gb['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_gb['duration_numeric'] =dataset_test_gb['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_gb['audio_filepath_numeric'] = dataset_test_gb['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_gb['audio_filepath_numeric'] = dataset_test_gb['audio_filepath'].str[-13:-5]

###dataset_test_gb['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_gb)
##################################### Accent IT ########################################
print('################################## Accent IT ###########################################')
dataset_test_it = pd.read_csv('test_it.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_it['duration_numeric'] = dataset_test_it['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_it['duration_numeric'] =dataset_test_it['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_it['audio_filepath_numeric'] = dataset_test_it['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_it['audio_filepath_numeric'] = dataset_test_it['audio_filepath'].str[-13:-5]

###dataset_test_it['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_it)
##################################### Accent RU ########################################
print('################################## Accent RU ###########################################')
dataset_test_ru = pd.read_csv('test_ru.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_ru['duration_numeric'] = dataset_test_ru['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_ru['duration_numeric'] =dataset_test_ru['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_ru['audio_filepath_numeric'] = dataset_test_ru['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_ru['audio_filepath_numeric'] = dataset_test_ru['audio_filepath'].str[-13:-5]

###dataset_test_ru['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_ru)
##################################### Accent US ########################################
print('################################## Accent US ###########################################')
dataset_test_us = pd.read_csv('test_us.txt', header=None, names=['audio_filepath','text','duration'])

# extract the numeric values of the durations from the third Column and store it in a new column called duration_numeric
dataset_test_us['duration_numeric'] = dataset_test_us['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
dataset_test_us['duration_numeric'] =dataset_test_us['duration_numeric'].div(10)
# extract the audio files ID values from the first Column and store it in a new column called audio_filepath_numeric
#dataset_test_us['audio_filepath_numeric'] = dataset_test_us['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

dataset_test_us['audio_filepath_numeric'] = dataset_test_us['audio_filepath'].str[-13:-5]

###dataset_test_us['audio_filepath_numeric']=re.search('AAA(.+?)ZZZ', text)
print(dataset_test_us)

##################################### Accent Mean ########################################

print('################################## Accent Mean ###########################################')
dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us']
dataset_name="dataset_test_"

for i in range(len(dataset_test_)):
  Accent_Values=dataset_test_[i]
  #print('dataset_test_'+Accent_Values+' mean =',Accent_Values)
  
  Accent_type=dataset_name+Accent_Values
  print(f'{Accent_type}_mean =',Accent_type)
print('################################## Accent Mean ###########################################')

print(np.mean(dataset_test_at['duration_numeric']))
print(np.mean(dataset_test_ca['duration_numeric']))
print(np.mean(dataset_test_ch['duration_numeric']))
print(np.mean(dataset_test_de_al['duration_numeric']))
print(np.mean(dataset_test_de_ni['duration_numeric']))
print(np.mean(dataset_test_de['duration_numeric']))
print(np.mean(dataset_test_fr['duration_numeric']))
print(np.mean(dataset_test_gb['duration_numeric']))
print(np.mean(dataset_test_it['duration_numeric']))
print(np.mean(dataset_test_ru['duration_numeric']))
print(np.mean(dataset_test_us['duration_numeric']))

# for i in range(1,12):
#   dataset_accent_all=[i]
#   print(i)
# Out:
# ################################## Accent AT ###########################################
#                                          audio_filepath  \
# 0     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ...                                                 ...
# 4490  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4491  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4492  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4493  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4494  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                    text            duration  \
# 0      "text": "er ist nach eustache de saint pierre...    "duration": 4.9}
# 1      "text": "eine erste kleinformatige vorstudie ...   "duration": 10.1}
# 2      "text": "er blieb ohne erfolg und lag in st\u...    "duration": 9.0}
# 3      "text": "mein garten ist teil eines kleingart...    "duration": 3.7}
# 4      "text": "was habe ich damals f\u00fcr einen u...    "duration": 3.6}
# ...                                                 ...                 ...
# 4490   "text": "es handelt sich heute um eine wohnst...    "duration": 5.8}
# 4491   "text": "wir m\u00fcssen sie blo\u00df verbes...    "duration": 4.2}
# 4492   "text": "unter abspaltung von wasser bildet s...    "duration": 6.8}
# 4493   "text": "die sammlung wurde von gro\u00dfherz...    "duration": 5.6}
# 4494   "text": "w\u00e4hrend der zeit des dritten re...    "duration": 6.8}
#
#       duration_numeric audio_filepath_numeric
# 0                  4.9               31449916
# 1                 10.1               19730674
# 2                  9.0               19703888
# 3                  3.7               18507972
# 4                  3.6               24131267
# ...                ...                    ...
# 4490               5.8               23706817
# 4491               4.2               21599214
# 4492               6.8               25132532
# 4493               5.6               23778312
# 4494               6.8               23358245
#
# [4495 rows x 5 columns]
# ################################## Accent CA ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 118  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 119  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 120  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 121  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 122  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0                       "text": "bundesliga verfehlte"   "duration": 3.1}
# 1     "text": "zuvor stand hier der bauernhof von h...   "duration": 4.9}
# 2     "text": "ein garten im stil des barock in ein...   "duration": 6.7}
# 3     "text": "der stein steht schr\u00e4g zu kirch...   "duration": 6.5}
# 4     "text": "auch aminos\u00e4uren k\u00f6nnen al...   "duration": 5.1}
# ..                                                 ...                ...
# 118         "text": "chris lorenzo und als police sgt"   "duration": 4.2}
# 119   "text": "selbst untereinander durften die kin...   "duration": 5.1}
# 120   "text": "sp\u00e4ter arbeitete sankey als ber...   "duration": 6.1}
# 121   "text": "sehr oft lautet der ratschlag eine p...   "duration": 6.3}
# 122   "text": "deutsche springderby in hamburgklein...   "duration": 5.3}
#
#      duration_numeric audio_filepath_numeric
# 0                 3.1               19575693
# 1                 4.9               19575694
# 2                 6.7               19575695
# 3                 6.5               19575696
# 4                 5.1               19575697
# ..                ...                    ...
# 118               4.2               26380610
# 119               5.1               26380611
# 120               6.1               26380612
# 121               6.3               26380613
# 122               5.3               26380614
#
# [123 rows x 5 columns]
# ################################## Accent CH ###########################################
#                                          audio_filepath  \
# 0     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ...                                                 ...
# 2903  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2904  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2905  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2906  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2907  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                    text            duration  \
# 0      "text": "auch posen und krakau waren mal haup...    "duration": 6.2}
# 1      "text": "in dieser funktion produzierte er di...    "duration": 8.3}
# 2      "text": "er besuchte zun\u00e4chst die stadts...    "duration": 7.3}
# 3               "text": "wir haben euch schon erwartet"    "duration": 2.8}
# 4      "text": "sie ist weiterhin aufsichtsratsmitgl...    "duration": 7.6}
# ...                                                 ...                 ...
# 2903   "text": "nach der machtergreifung der nationa...   "duration": 10.3}
# 2904   "text": "in den folgejahren hatten die deutsc...    "duration": 4.7}
# 2905   "text": "der schwerpunkt von anke abrahams fo...    "duration": 7.8}
# 2906   "text": "als tatsachen gelten in abgrenzung z...    "duration": 6.7}
# 2907   "text": "daneben arbeitete sie als wissenscha...    "duration": 8.5}
#
#       duration_numeric audio_filepath_numeric
# 0                  6.2               17784450
# 1                  8.3               20428000
# 2                  7.3               32231734
# 3                  2.8               17783886
# 4                  7.6               32230545
# ...                ...                    ...
# 2903              10.3               32239244
# 2904               4.7               28893969
# 2905               7.8               32229878
# 2906               6.7               20375474
# 2907               8.5               32224615
#
# [2908 rows x 5 columns]
# ################################## Accent DE_AL ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 719  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 720  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 721  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 722  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 723  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0     "text": "dort sind inzwischen mehrere listen ...   "duration": 5.5}
# 1     "text": "ma\u00dfgeblich war auch sein wirken...   "duration": 6.4}
# 2     "text": "zu beiden st\u00e4dten besteht auch ...   "duration": 3.8}
# 3     "text": "sp\u00e4ter war er erster vorsitzend...   "duration": 5.3}
# 4              "text": "wiesbaden ver\u00f6ffentlicht"   "duration": 3.2}
# ..                                                 ...                ...
# 719   "text": "darum glaube ich m\u00fcssen wir die...   "duration": 5.5}
# 720   "text": "der haushaltsausschuss kann somit da...   "duration": 5.7}
# 721   "text": "mit ihr sollen bedeutende pers\u00f6...   "duration": 6.3}
# 722   "text": "wellenkraft l\u00e4sst sich nur an b...   "duration": 5.2}
# 723   "text": "agent green wurde nicht alleine verw...   "duration": 7.0}
#
#      duration_numeric audio_filepath_numeric
# 0                 5.5               19270327
# 1                 6.4               19270328
# 2                 3.8               19270329
# 3                 5.3               19270331
# 4                 3.2               19270332
# ..                ...                    ...
# 719               5.5               27309480
# 720               5.7               27309484
# 721               6.3               27309488
# 722               5.2               27309489
# 723               7.0               27309491
#
# [724 rows x 5 columns]
# ################################## Accent DE_NI ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 666  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 667  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 668  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 669  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 670  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0     "text": "der inflation\u00e4re gebrauch von s...   "duration": 8.1}
# 1     "text": "eduard musste eine vollbremsung hinl...   "duration": 3.8}
# 2     "text": "ich brauche was richtiges gegen den ...   "duration": 3.8}
# 3                   "text": "lass uns alles abfackeln"   "duration": 3.1}
# 4     "text": "es ist halt ein winkel keine fl\u00e...   "duration": 3.7}
# ..                                                 ...                ...
# 666   "text": "jodorowsky ist kind einer j\u00fcdis...   "duration": 6.1}
# 667   "text": "es geh\u00f6rt zur katholischen di\u...   "duration": 6.5}
# 668   "text": "die maguindanaomoslems sind dagegen ...   "duration": 7.9}
# 669   "text": "dar\u00fcber hinaus werden auch dien...   "duration": 6.5}
# 670   "text": "auch spracherkennung ist eine m\u00f...   "duration": 4.2}
#
#      duration_numeric audio_filepath_numeric
# 0                 8.1               18043068
# 1                 3.8               18043069
# 2                 3.8               18043070
# 3                 3.1               18043071
# 4                 3.7               18043072
# ..                ...                    ...
# 666               6.1               30222587
# 667               6.5               30222593
# 668               7.9               30222598
# 669               6.5               30222599
# 670               4.2               30222622
#
# [671 rows x 5 columns]
# ################################## Accent DE ###########################################
#                                           audio_filepath  \
# 0      {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1      {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2      {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3      {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4      {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ...                                                  ...
# 36499  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 36500  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 36501  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 36502  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 36503  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                     text           duration  \
# 0       "text": "nun m\u00fcssen meines erachtens kon...   "duration": 8.1}
# 1       "text": "hierf\u00fcr gibt es kein patentrezept"   "duration": 3.0}
# 2       "text": "es sind kaum gebrauchsspuren zu erke...   "duration": 2.6}
# 3       "text": "bei der hitze schwitzt man so stark ...   "duration": 5.5}
# 4       "text": "vier jahrzehnte lang organisierte er...   "duration": 8.1}
# ...                                                  ...                ...
# 36499           "text": "nikolai darf als aufpasser mit"   "duration": 4.9}
# 36500   "text": "zum neu eingef\u00fchrten abendprogr...   "duration": 6.1}
# 36501   "text": "die verhandlungen finden unter aussc...   "duration": 4.9}
# 36502   "text": "derzeit ist sie vermutlich als jazzm...   "duration": 6.1}
# 36503   "text": "kannst du schon alleine schaukeln od...   "duration": 5.2}
#
#        duration_numeric audio_filepath_numeric
# 0                   8.1               21370968
# 1                   3.0               17687144
# 2                   2.6               18108616
# 3                   5.5               18204446
# 4                   8.1               20549710
# ...                 ...                    ...
# 36499               4.9               18525135
# 36500               6.1               32192490
# 36501               4.9               17910892
# 36502               6.1               26952486
# 36503               5.2               17410557
#
# [36504 rows x 5 columns]
# ################################## Accent FR ###########################################
#                                          audio_filepath  \
# 0     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ...                                                 ...
# 1410  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1411  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1412  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1413  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1414  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                    text           duration  \
# 0      "text": "ein gro\u00dfer teil der conciergeri...   "duration": 7.1}
# 1          "text": "ganzj\u00e4hrig wehen starke winde"   "duration": 4.1}
# 2                           "text": "etwa zehn prozent"   "duration": 2.4}
# 3      "text": "belgrad ist die hauptstadt von serbien"   "duration": 4.4}
# 4      "text": "sechs weitere zeigen spuren einer ro...   "duration": 4.6}
# ...                                                 ...                ...
# 1410   "text": "du benutzt st\u00e4ndig irgendwelche...   "duration": 4.9}
# 1411   "text": "und das wo mein bruder doch an arach...   "duration": 5.0}
# 1412            "text": "mir ist der appetit vergangen"   "duration": 3.4}
# 1413   "text": "ordentliche fahrradstellpl\u00e4tze ...   "duration": 7.4}
# 1414   "text": "seither gibt es bei ihm nur noch tre...   "duration": 4.1}
#
#       duration_numeric audio_filepath_numeric
# 0                  7.1               19625120
# 1                  4.1               32367831
# 2                  2.4               18364178
# 3                  4.4               18364180
# 4                  4.6               19674074
# ...                ...                    ...
# 1410               4.9               18177529
# 1411               5.0               18177531
# 1412               3.4               18177532
# 1413               7.4               18177536
# 1414               4.1               18177540
#
# [1415 rows x 5 columns]
# ################################## Accent GB ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 143  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 144  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 145  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 146  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 147  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0     "text": "alter falter das hat mir gerade noch...   "duration": 4.4}
# 1     "text": "und so geht es im g\u00e4nsemarsch b...   "duration": 5.5}
# 2                                         "text": "ja"   "duration": 2.1}
# 3                                       "text": "drei"   "duration": 2.4}
# 4                                       "text": "zwei"   "duration": 2.4}
# ..                                                 ...                ...
# 143   "text": "wir begr\u00fc\u00dfen sie von ganze...   "duration": 4.9}
# 144   "text": "der bachelor muss in keinem bestimmt...   "duration": 4.9}
# 145   "text": "zus\u00e4tzlich war zum bremsen eine...   "duration": 6.6}
# 146   "text": "sie sind formal den kurzgeschichten ...   "duration": 6.6}
# 147   "text": "dies f\u00fchrte teilweise in frankr...   "duration": 6.6}
#
#      duration_numeric audio_filepath_numeric
# 0                 4.4               18597258
# 1                 5.5               18597260
# 2                 2.1               22265116
# 3                 2.4               22265120
# 4                 2.4               22265123
# ..                ...                    ...
# 143               4.9               23364671
# 144               4.9               23364677
# 145               6.6               23364678
# 146               6.6               23364680
# 147               6.6               23364686
#
# [148 rows x 5 columns]
# ################################## Accent IT ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 973  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 974  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 975  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 976  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 977  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0     "text": "er wird in ein krankenhaus eingelief...   "duration": 4.6}
# 1         "text": "ich sagte dir ich hatte hoffnungen"   "duration": 4.5}
# 2         "text": "spirituals waren ebenfalls beliebt"   "duration": 5.3}
# 3     "text": "als berufsboxer k\u00e4mpfte ted mor...   "duration": 9.3}
# 4     "text": "ich bin schon sehr gespannt auf ihre...   "duration": 5.8}
# ..                                                 ...                ...
# 973   "text": "extra f\u00fcr dieses schiff mit neu...   "duration": 6.3}
# 974                 "text": "sein auto wird gestohlen"   "duration": 3.0}
# 975   "text": "dies stellt eine erhebliche bedrohun...   "duration": 8.6}
# 976   "text": "es hei\u00dft er habe ein zur\u00fcc...   "duration": 5.1}
# 977   "text": "dies war die folge der reichsexekuti...   "duration": 8.9}
#
#      duration_numeric audio_filepath_numeric
# 0                 4.6               26205614
# 1                 4.5               26205616
# 2                 5.3               26205618
# 3                 9.3               26432582
# 4                 5.8               26432583
# ..                ...                    ...
# 973               6.3               23554686
# 974               3.0               23554687
# 975               8.6               23554688
# 976               5.1               23554689
# 977               8.9               23554690
#
# [978 rows x 5 columns]
# ################################## Accent RU ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 968  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 969  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 970  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 971  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 972  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0                   "text": "was solls ich bin bereit"   "duration": 4.6}
# 1     "text": "wenn nicht dann legt man sie irgendw...   "duration": 4.3}
# 2     "text": "die stadt ist ein wechsel aus histor...   "duration": 5.5}
# 3     "text": "diesen schlussfolgerungen fehlen jed...   "duration": 5.9}
# 4     "text": "urspr\u00fcnglich geh\u00f6rte das a...   "duration": 6.9}
# ..                                                 ...                ...
# 968               "text": "sie kramte in ihrer tasche"   "duration": 2.2}
# 969   "text": "libreville ist die hauptstadt von ga...   "duration": 3.5}
# 970   "text": "das ramponierte image haben sie sich...   "duration": 4.7}
# 971   "text": "er macht einen unterforderten eindruck"   "duration": 3.4}
# 972   "text": "mit der kippe sind sie f\u00fcr ihr ...   "duration": 4.3}
#
#      duration_numeric audio_filepath_numeric
# 0                 4.6               18520278
# 1                 4.3               26888041
# 2                 5.5               27399033
# 3                 5.9               27399034
# 4                 6.9               27399035
# ..                ...                    ...
# 968               2.2               17645865
# 969               3.5               17645866
# 970               4.7               18862913
# 971               3.4               18862914
# 972               4.3               18862915
#
# [973 rows x 5 columns]
# ################################## Accent US ###########################################
#                                         audio_filepath  \
# 0    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4    {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ..                                                 ...
# 286  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 287  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 288  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 289  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 290  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                   text           duration  \
# 0     "text": "allein die unterst\u00fctzung der v\...   "duration": 7.7}
# 1     "text": "diese auffassungen kommen in meiner ...   "duration": 5.4}
# 2                               "text": "das ist klar"   "duration": 2.5}
# 3     "text": "der sich aus der beendigung dieser a...   "duration": 7.2}
# 4            "text": "steindl wohnt in purbach am see"   "duration": 4.2}
# ..                                                 ...                ...
# 286   "text": "erstens sollten sie sicherstellen da...   "duration": 8.5}
# 287   "text": "allgemein bekannt sind die irreversi...   "duration": 8.6}
# 288   "text": "als der erste ehemann verstarb zog b...   "duration": 7.0}
# 289   "text": "erhalten blieb vorerst die kircht\u0...   "duration": 6.5}
# 290   "text": "der fokus liegt vor allem auf market...   "duration": 6.4}
#
#      duration_numeric audio_filepath_numeric
# 0                 7.7               29271362
# 1                 5.4               21563903
# 2                 2.5               21563904
# 3                 7.2               21563905
# 4                 4.2               27703547
# ..                ...                    ...
# 286               8.5               22546390
# 287               8.6               22546391
# 288               7.0               22546392
# 289               6.5               22546393
# 290               6.4               22546394
#
# [291 rows x 5 columns]
# ################################## Accent Mean ###########################################
# dataset_test_at_mean = dataset_test_at
# dataset_test_ca_mean = dataset_test_ca
# dataset_test_ch_mean = dataset_test_ch
# dataset_test_de_al_mean = dataset_test_de_al
# dataset_test_de_ni_mean = dataset_test_de_ni
# dataset_test_de_mean = dataset_test_de
# dataset_test_fr_mean = dataset_test_fr
# dataset_test_gb_mean = dataset_test_gb
# dataset_test_it_mean = dataset_test_it
# dataset_test_ru_mean = dataset_test_ru
# dataset_test_us_mean = dataset_test_us
# ################################## Accent Mean ###########################################
# 5.1273192436040045
# 5.942276422764228
# 5.504779917469051
# 5.370441988950277
# 5.6436661698956785
# 4.842688472496165
# 5.236254416961131
# 5.5195945945945954
# 5.891308793456033
# 4.192086330935251
# 5.838144329896908

# %%
print('################################## Accent Mean ###########################################')
dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us']
dataset_test_[0]
for i in range(len(dataset_test_)):
  Accent_Values=dataset_test_[i]
  print('dataset_test_'+Accent_Values+' mean =',Accent_Values)
print('################################## Accent Mean ###########################################')
# Out:
# ################################## Accent Mean ###########################################
# dataset_test_at mean = at
# dataset_test_ca mean = ca
# dataset_test_ch mean = ch
# dataset_test_de_al mean = de_al
# dataset_test_de_ni mean = de_ni
# dataset_test_de mean = de
# dataset_test_fr mean = fr
# dataset_test_gb mean = gb
# dataset_test_it mean = it
# dataset_test_ru mean = ru
# dataset_test_us mean = us
# ################################## Accent Mean ###########################################

# %%
#   return np.mean(DatasetName)
 

print('################################## Accent Mean ###########################################')
list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us']
dataset_dataset_test_=pd.DataFrame(list_dataset_test_, columns=['accent']) 

dataset_name="dataset_test_"
dataset_column="['duration_numeric']"

dataset_all_accent=[] # create a dataset called "dataset_all_accent" required column of mean calculations of all Accents
list_all_accent_cal=[] # list of the results of mean calculations of all accents
list_all_accent=[]
list_all_accent_mean=[] # create a dataset called "list_all_accent_mean" contains the mean calculations of all Accents
for i in range(len(list_dataset_test_)):
  
  Accent_Values=dataset_test_[i]
  Accent_type=dataset_name+Accent_Values+dataset_column
  ###list_all_accent_cal.insert(i,5+i)
  #list_all_accent_cal[i]=np.mean(dataset_test_at['duration_numeric'])
  ###print(f' \'np.mean({Accent_type}\'),')
  temp_list=f' {Accent_type}'
  temp_mean_list=f' np.mean({Accent_type})'

  

  #list_all_accent_cal.insert(i,np.mean(temp_list))

  print(f'np.mean({Accent_type})')
  # create a dataset called "list_all_accent_mean" contains the mean calculations for all Accents
  ###dataset_all_accent.insert(i,Accent_type)
  list_all_accent.insert(i,temp_list)
  list_all_accent_mean.insert(i,temp_mean_list)
  
# print('#'*60,'dataset_all_accent')
# print(dataset_all_accent,'\n')

print('#'*30,'list_all_accent=','#'*30)
#print(f'{list_all_accent}',sep=os.linesep)
print(f' \n {list_all_accent}')


print('#'*30,'list_all_accent_mean=','#'*30)
#print(f'{list_all_accent_mean}',sep=os.linesep)
print(f'\n  {list_all_accent_mean}')

print('#'*30,'list_all_accent_cal=','#'*30)
print(f'\n  {list_all_accent_cal}')


 

 
# np.mean(dataset_test_at['duration_numeric'])
# Out:
# ################################## Accent Mean ###########################################
# np.mean(dataset_test_at['duration_numeric'])
# np.mean(dataset_test_ca['duration_numeric'])
# np.mean(dataset_test_ch['duration_numeric'])
# np.mean(dataset_test_de_al['duration_numeric'])
# np.mean(dataset_test_de_ni['duration_numeric'])
# np.mean(dataset_test_de['duration_numeric'])
# np.mean(dataset_test_fr['duration_numeric'])
# np.mean(dataset_test_gb['duration_numeric'])
# np.mean(dataset_test_it['duration_numeric'])
# np.mean(dataset_test_ru['duration_numeric'])
# np.mean(dataset_test_us['duration_numeric'])
# ############################## list_all_accent= ##############################
#
#  [" dataset_test_at['duration_numeric']", " dataset_test_ca['duration_numeric']", " dataset_test_ch['duration_numeric']", " dataset_test_de_al['duration_numeric']", " dataset_test_de_ni['duration_numeric']", " dataset_test_de['duration_numeric']", " dataset_test_fr['duration_numeric']", " dataset_test_gb['duration_numeric']", " dataset_test_it['duration_numeric']", " dataset_test_ru['duration_numeric']", " dataset_test_us['duration_numeric']"]
# ############################## list_all_accent_mean= ##############################
#
#   [" np.mean(dataset_test_at['duration_numeric'])", " np.mean(dataset_test_ca['duration_numeric'])", " np.mean(dataset_test_ch['duration_numeric'])", " np.mean(dataset_test_de_al['duration_numeric'])", " np.mean(dataset_test_de_ni['duration_numeric'])", " np.mean(dataset_test_de['duration_numeric'])", " np.mean(dataset_test_fr['duration_numeric'])", " np.mean(dataset_test_gb['duration_numeric'])", " np.mean(dataset_test_it['duration_numeric'])", " np.mean(dataset_test_ru['duration_numeric'])", " np.mean(dataset_test_us['duration_numeric'])"]
# ############################## list_all_accent_cal= ##############################
#
#   []

# %%
dataset_all_accent= pd.DataFrame (list_all_accent, columns = ['accent'])
dataset_all_accent_mean = pd.DataFrame (list_all_accent_mean, columns = ['mean_of_accent'])
# dataset_all_accent_mean['Column'] = df['Column'].apply(ast.literal_eval)
dataset_all_accent_mean
# dataset_all_accent_mean.mean_of_all_accent[0]
# Out:
#                                       mean_of_accent
# 0       np.mean(dataset_test_at['duration_numeric'])
# 1       np.mean(dataset_test_ca['duration_numeric'])
# 2       np.mean(dataset_test_ch['duration_numeric'])
# 3    np.mean(dataset_test_de_al['duration_numeric'])
# 4    np.mean(dataset_test_de_ni['duration_numeric'])
# 5       np.mean(dataset_test_de['duration_numeric'])
# 6       np.mean(dataset_test_fr['duration_numeric'])
# 7       np.mean(dataset_test_gb['duration_numeric'])
# 8       np.mean(dataset_test_it['duration_numeric'])
# 9       np.mean(dataset_test_ru['duration_numeric'])
# 10      np.mean(dataset_test_us['duration_numeric'])

# %%
####################################Insert Accent Loop##################################################
#######this output will written in an external py file called dataset_accent.py ########################
############## To implement it here in colab and get the mean of all accent ############################

list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us','stop']
list1=['']
Accent_=0
print('#'*60,'Insert Accent Loop','#'*60)
for j in list_dataset_test_:
  for i in range(0,11):
    #print(i)
    # print(onetime)
    if j!='stop':
      #print(f'Accent_{j}={dataset_all_accent_mean.mean_of_all_accent[i]}')
      print(f"\n print(' Accent_{j}_Duration_mean= ')")
      print(f"\n print({dataset_all_accent_mean.mean_of_accent[i]})")
      stopcal=i+1
      j=list_dataset_test_[stopcal]
  if j=='stop':
    break
  print('#'*60,{j},{i},'#'*60)
# Out:
# ############################################################ Insert Accent Loop ############################################################
#
#  print(' Accent_at_Duration_mean= ')
#
#  print( np.mean(dataset_test_at['duration_numeric']))
#
#  print(' Accent_ca_Duration_mean= ')
#
#  print( np.mean(dataset_test_ca['duration_numeric']))
#
#  print(' Accent_ch_Duration_mean= ')
#
#  print( np.mean(dataset_test_ch['duration_numeric']))
#
#  print(' Accent_de_al_Duration_mean= ')
#
#  print( np.mean(dataset_test_de_al['duration_numeric']))
#
#  print(' Accent_de_ni_Duration_mean= ')
#
#  print( np.mean(dataset_test_de_ni['duration_numeric']))
#
#  print(' Accent_de_Duration_mean= ')
#
#  print( np.mean(dataset_test_de['duration_numeric']))
#
#  print(' Accent_fr_Duration_mean= ')
#
#  print( np.mean(dataset_test_fr['duration_numeric']))
#
#  print(' Accent_gb_Duration_mean= ')
#
#  print( np.mean(dataset_test_gb['duration_numeric']))
#
#  print(' Accent_it_Duration_mean= ')
#
#  print( np.mean(dataset_test_it['duration_numeric']))
#
#  print(' Accent_ru_Duration_mean= ')
#
#  print( np.mean(dataset_test_ru['duration_numeric']))
#
#  print(' Accent_us_Duration_mean= ')
#
#  print( np.mean(dataset_test_us['duration_numeric']))

# %%
import os
# remove the script if exists 
# os.remove("dataset_accent.py")
# open script to write in the calculation of Mean of all accent
dataset_accent_write_file = open("dataset_accent.py",'w')
dataset_accent_write_file.write("np.mean(dataset_test_at['duration_numeric'])")
dataset_accent_write_file.close()

# %%
import os
! cp /content/test_us.txt
# read the script
Read_dataset_file=open("dataset_accent.py",'r')
print(Read_dataset_file.read())
# Out:
# cp: missing destination file operand after '/content/test_us.txt'
# Try 'cp --help' for more information.
# np.mean(dataset_test_at['duration_numeric'])

# %% [markdown]
# #### Run the fiel dataset_accent.py

# %%
# implement the script dataset_accent.py t ocalculate all the means and store them in a new dataset 
! cp /content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/dataset_accent.py   /content/dataset_accent.py

exec(open("dataset_accent.py").read())
# Out:
#  Accent_at_Duration_mean=
# 5.1273192436040045
#  Accent_ca_Duration_mean=
# 5.942276422764228
#  Accent_ch_Duration_mean=
# 5.504779917469051
#  Accent_de_al_Duration_mean=
# 5.370441988950277
#  Accent_de_ni_Duration_mean=
# 5.6436661698956785
#  Accent_de_Duration_mean=
# 4.842688472496165
#  Accent_fr_Duration_mean=
# 5.236254416961131
#  Accent_gb_Duration_mean=
# 5.5195945945945954
#  Accent_it_Duration_mean=
# 5.891308793456033
#  Accent_ru_Duration_mean=
# 4.192086330935251
#  Accent_us_Duration_mean=
# 5.838144329896908

# %%
# # add to the script
# datei = open("test3.py",'a')
# datei.write("\n np.mean(dataset_test_ca['duration_numeric'])")
# datei.close()

# %%
##############  store the mean results of all Accent in a dataframep##################################################
########################this output will written to a list and dataframe #############################################
import pandas as pd 
dataset_accent_all_Duration_mean_result=pd.DataFrame({'accent_type':['Accent_at_Duration_mean=', 'Accnt_ca_Duration_mean=' ,'Accnt_ch_Duration_mean=' , 'Accnt_de_al_Duration_mean=' , 'Accnt_de_ni_Duration_mean=' ,
                                                     'Accnt_de_Duration_mean=' ,'Accnt_fr_Duration_mean=' , 'Accnt_gb_Duration_mean=' , 'Accnt_it_Duration_mean=' , 'Accnt_ru_Duration_mean=' , 'Accnt_us_Duration_mean=' ] ,
                                      'accent_Duration_mean':[5.1273192436040045,5.942276422764228,5.504779917469051,5.370441988950277,5.6436661698956785,4.842688472496165,
                                            5.236254416961131,5.5195945945945954,5.891308793456033,4.192086330935251,5.838144329896908]    })


  
 
print('#'*60,'dataset_accent_all_Duration_mean_result','#'*60)
print(dataset_accent_all_Duration_mean_result)
print('#'*120)
# list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us','stop']
# list1=['']
# Accent_=0

# list_accent_all_mean_result=[]
# dataset_all_accent_mean=[]
# print('#'*60,'Insert Accent Loop','#'*60)
# for j in list_dataset_test_:
#   for i in range(0,11):
#     #print(i)
#     # print(onetime)
#     if j!='stop':
#       #print(f'Accent_{j}={dataset_all_accent_mean.mean_of_all_accent[i]}')
#       print(f"\n print(' Accent_{j}= ')")
#       print(f"\n print({dataset_all_accent_mean.mean_of_all_accent[i]})")
#       stopcal=i+1
#       j=list_dataset_test_[stopcal]
#       ####list_accent_all_mean_result[i]=dataset_all_accent_mean.mean_of_all_accent[i]
#   if j=='stop':
#     break
#   print('#'*60,{j},{i},'#'*60)

# dataset_accent_all_mean_result=pd.DataFrame(list_accent_all_mean_result,columns=[''])
# print('#'*60,'dataset_accent_all_mean_result','#'*60)
# Out:
# ############################################################ dataset_accent_all_Duration_mean_result ############################################################
#                    accent_type  accent_Duration_mean
# 0     Accent_at_Duration_mean=              5.127319
# 1      Accnt_ca_Duration_mean=              5.942276
# 2      Accnt_ch_Duration_mean=              5.504780
# 3   Accnt_de_al_Duration_mean=              5.370442
# 4   Accnt_de_ni_Duration_mean=              5.643666
# 5      Accnt_de_Duration_mean=              4.842688
# 6      Accnt_fr_Duration_mean=              5.236254
# 7      Accnt_gb_Duration_mean=              5.519595
# 8      Accnt_it_Duration_mean=              5.891309
# 9      Accnt_ru_Duration_mean=              4.192086
# 10     Accnt_us_Duration_mean=              5.838144
# ########################################################################################################################

# %%
# add the accent_Duration_mean column to the dataset_test_at
dataset_test_at['accent_Duration_mean'] = np.where(dataset_test_at['audio_filepath']!=np.NaN,5.127319, '000')
dataset_test_at
# Out:
#                                          audio_filepath  \
# 0     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 1     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 2     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 3     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4     {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# ...                                                 ...
# 4490  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4491  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4492  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4493  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
# 4494  {"audio_filepath": "/ds/audio/CommonVoiceCorpu...
#
#                                                    text            duration  \
# 0      "text": "er ist nach eustache de saint pierre...    "duration": 4.9}
# 1      "text": "eine erste kleinformatige vorstudie ...   "duration": 10.1}
# 2      "text": "er blieb ohne erfolg und lag in st\u...    "duration": 9.0}
# 3      "text": "mein garten ist teil eines kleingart...    "duration": 3.7}
# 4      "text": "was habe ich damals f\u00fcr einen u...    "duration": 3.6}
# ...                                                 ...                 ...
# 4490   "text": "es handelt sich heute um eine wohnst...    "duration": 5.8}
# 4491   "text": "wir m\u00fcssen sie blo\u00df verbes...    "duration": 4.2}
# 4492   "text": "unter abspaltung von wasser bildet s...    "duration": 6.8}
# 4493   "text": "die sammlung wurde von gro\u00dfherz...    "duration": 5.6}
# 4494   "text": "w\u00e4hrend der zeit des dritten re...    "duration": 6.8}
#
#       duration_numeric audio_filepath_numeric accent_Duration_mean
# 0                  4.9               31449916             5.127319
# 1                 10.1               19730674             5.127319
# 2                  9.0               19703888             5.127319
# 3                  3.7               18507972             5.127319
# 4                  3.6               24131267             5.127319
# ...                ...                    ...                  ...
# 4490               5.8               23706817             5.127319
# 4491               4.2               21599214             5.127319
# 4492               6.8               25132532             5.127319
# 4493               5.6               23778312             5.127319
# 4494               6.8               23358245             5.127319
#
# [4495 rows x 6 columns]

# %%
# change dataset_test_at['audio_filepath_numeric'] from object to numeric
dataset_test_at['audio_filepath_numeric'] = pd.to_numeric(dataset_test_at['audio_filepath_numeric'])
dataset_test_at.dtypes
# Out:
# audio_filepath             object
# text                       object
# duration                   object
# duration_numeric          float64
# audio_filepath_numeric      int64
# accent_Duration_mean       object
# dtype: object

# %%
dataset_accent_all_Duration_mean_result
# Out:
#                    accent_type  accent_Duration_mean
# 0     Accent_at_Duration_mean=              5.127319
# 1      Accnt_ca_Duration_mean=              5.942276
# 2      Accnt_ch_Duration_mean=              5.504780
# 3   Accnt_de_al_Duration_mean=              5.370442
# 4   Accnt_de_ni_Duration_mean=              5.643666
# 5      Accnt_de_Duration_mean=              4.842688
# 6      Accnt_fr_Duration_mean=              5.236254
# 7      Accnt_gb_Duration_mean=              5.519595
# 8      Accnt_it_Duration_mean=              5.891309
# 9      Accnt_ru_Duration_mean=              4.192086
# 10     Accnt_us_Duration_mean=              5.838144

# %% [markdown]
# ###**<font color="1497d4">Bar charts Duration's Accent  </font>**

# %% [markdown]
# ####**<font color="1497d4">Bar chart: </font>** **x='accent', y = 'accent_Duration_mean'**

# %%
#plt.subplot(2,3,1)
#fig, axs = plt.subplots(2, 2, figsize=(15, 15))
#plt.legend()

# list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us','stop']
# list1=['']
# Accent_=0
# print('#'*60,'Insert Accent Loop','#'*60)
# for j in list_dataset_test_:
#   for i in range(0,11):
#     #print(i)
#     # print(onetime)
#     if j!='stop':
#       #print(f'Accent_{j}={dataset_all_accent_mean.mean_of_all_accent[i]}')
#       print(f"\n print(' Accent_{j}_Duration_mean= ')")
#       print(f"\n print({dataset_all_accent_mean.mean_of_all_accent[i]})")
#       stopcal=i+1
#       j=list_dataset_test_[stopcal]
#   if j=='stop':
#     break
#   print('#'*60,{j},{i},'#'*60)
# To show only the Accent letters ,we add neu column called accent in dataset_accent_all_Duration_mean_result
list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us','stop']
list_dataset_test_accent=['Österreichisches Deutsch','Kanadisches Deutsch','Schweizerdeutsch','Alemannische Färbung,Schweizer Standart Deutsch','Niederländisch Deutsch',' Deutschland Deutsch','Französisch Deutsch	','Britisches Deutsch',' Italienisch Deutsch'
,'Russisch Deutsch','Amerikanisches Deutsch']


dataset_accent_all_Duration_mean_result['accent']=dataset_dataset_test_['accent']
import seaborn as sns
from matplotlib import pyplot as plt


################################## Accent AT ###########################################
# position of the figure and figure;s size 
figure_duriation_distribution_accent=plt.figure(12,figsize=(10,10))  
#plt.subplots(figure's number per column,figure's number per row)
####>>>>>ax_duriation_distribution_accent_at=figure_duriation_distribution_accent.add_subplot(3,4,1)

# for i in range(len(dataset_accent_all_Duration_mean_result)):
dataset_test_at['accent_Duration_mean'] = np.where(dataset_test_at['audio_filepath']!=np.NaN,5.127319, '000')

# plt.xlabel("Speaker's accent - Austria")
# plt.ylabel("Duriation Distribution of Audiofiles")
# plt.plot(dataset_test_at['accent_Duration_mean'],dataset_test_at['audio_filepath_numeric'], lw=3, ms=20)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title('Duration\'s mean for all Accents',fontdict  = font1)


ax = sns.barplot(x = 'accent', y = 'accent_Duration_mean', data = dataset_accent_all_Duration_mean_result)
plt.savefig('plotBarDiagrams_Accent_Duration.png')

# %% [markdown]
# ####**<font color="1497d4">Bar chart: All Accent -Gender</font>** **x='accent', y = 'accent_Duration_mean' according to gender Accent ='all Accent'**

# %%
############################## Bar chart: x='accent', y = 'accent_Duration_mean' according to the gender - Accent ='all Accent'#######################################
print("################################## Bar chart: x='accent', y = 'accent_Duration_mean' according to the gender - Accent ='all Accent' ###########################################")
##### def plotBarChartsDurrationGenderAllAccent():
list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us']
list_dataset_test_accent=['Österreichisches Deutsch','Kanadisches Deutsch','Schweizerdeutsch','Alemannische Färbung,Schweizer Standart Deutsch','Niederländisch Deutsch','Deutschland Deutsch',
                          'Französisch Deutsch','Britisches Deutsch','Italienisch Deutsch'
,'Russisch Deutsch','Amerikanisches Deutsch']


# list_dataset_test_=['de_al']
# list_dataset_test_accent=['Alemannische Färbung,Schweizer Standart Deutsch']



# list_dataset_test_=['at']
# list_dataset_test_accent=['Österreichisches Deutsch']

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
  
data_2 = {'Accent_short':list_dataset_test_,'Accent_long': list_dataset_test_accent}
dataset_accent = pd.DataFrame(data_2)



 
############################# 1- reading the dataset ##########################################################



for i in range(0,len(dataset_accent)):

  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  accent_short_var=dataset_accent['Accent_short'][i]
  accent_long_var=dataset_accent['Accent_long'][i]

  ##

  # dataset_accent=f'dataset_test_{i}'
  # textfile_name=f'test_{i}.txt'
  dataset_test_ca = pd.read_csv(f'test_{accent_short_var}.txt', header=None, names=['audio_filepath','text','duration'])
  

  # dataset_test_ca=f'dataset_test_{i}'
  # extract the numeric values of the durations from the third Column and store it in a new column called
  dataset_test_ca['duration_numeric'] = dataset_test_ca['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
  dataset_test_ca['duration_numeric'] =dataset_test_ca['duration_numeric'].div(10)
  # extract the numeric values of the durations from the third Column and store it in a new column called 
  #dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

  dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].str[-13:-5]
  


  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
  dataset_test_ca['audio_filepath_numeric']=dataset_test_ca['audio_filepath_numeric'].astype('int')
  
  
  ############################# 3- Drop all NaN gender and NaN Accent values, and show only the female gender and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[(dataset_validated_tsv['gender'] != 'female') | (dataset_validated_tsv['gender'].isna())| 
  (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  #dataset_validated_tsv
 
  ############################# 4- Merge using audio_filepath_numeric column ##################################
  ####################5-calculate the Mean of duration when the gender is female###########################
  dataset_test_ca_validated_tsv_female=pd.merge(dataset_test_ca,dataset_validated_tsv)
  dataset_test_ca_validated_tsv_female['gender']=dataset_test_ca_validated_tsv_female['gender'].astype("string")
  dataset_test_ca_validated_tsv_female
  dataset_test_ca_validated_tsv_female['accent_Duration_mean_gender']=np.mean(dataset_test_ca_validated_tsv_female['duration_numeric'])
  

  
  ############################# 6- reading the dataset ##########################################################
  ############################# 7- extract the audio_filepath number and change them to integer################## 
  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  #dataset_test_ca = pd.read_csv(f'test_{accent_short_var}.txt', header=None, names=['audio_filepath','text','duration'])
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')




  
  ############################# 8- Drop all NaN gender and NaN Accent values, and show only the male gender and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[(dataset_validated_tsv['gender'] != 'male') | (dataset_validated_tsv['gender'].isna())| (dataset_validated_tsv['accents'].isna())
  | (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)

  ############################# 9- Merge using audio_filepath_numeric column ##################################
  dataset_test_ca_validated_tsv_male=pd.merge(dataset_test_ca,dataset_validated_tsv)
  dataset_test_ca_validated_tsv_male['gender']=dataset_test_ca_validated_tsv_male['gender'].astype("string")

 



  #################### 10- calculate the Mean of duration when the gender is male###########################
  dataset_test_ca_validated_tsv_male['accent_Duration_mean_gender']=np.mean(dataset_test_ca_validated_tsv_male['duration_numeric'])
  #dataset_test_ca_validated_tsv_male
  ###### add/append the upper dataset dataset_test_ca_validated_tsv_female to the lower dataset dataset_test_ca_validated_tsv_male###########################
  ###### and call the result dataset_test_ca_validated_tsv_family

#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_test_ca_validated_tsv_female.empty and not dataset_test_ca_validated_tsv_male.empty:
    dataset_test_ca_validated_tsv_family=dataset_test_ca_validated_tsv_female.append(dataset_test_ca_validated_tsv_male)
  elif dataset_test_ca_validated_tsv_female.empty and not dataset_test_ca_validated_tsv_male.empty:
    dataset_test_ca_validated_tsv_family=dataset_test_ca_validated_tsv_male
  elif dataset_test_ca_validated_tsv_male.empty and not dataset_test_ca_validated_tsv_female.empty:
    dataset_test_ca_validated_tsv_family=dataset_test_ca_validated_tsv_female
  else:
    data_3={'gender':['female','male'],'accent_Duration_mean_gender':[0,0]}
    dataset_test_ca_validated_tsv_family=pd.DataFrame(data_3)

    ################### 11- plot the dataset_test_ca_validated_tsv_family in Bar Chart #######################

  figure_duriation_distribution_accent=plt.figure(12,figsize=(20,20))  
  #plt.subplots(figure's number per column,figure's number per row)

  # Sup_plot_position=f'dataset_test_{i}'

  # Sup_plot_position=Sup_plot_position.astype(int)
  ax_duriation_distribution_accent_at=figure_duriation_distribution_accent.add_subplot(3,4,i+1)
  font1 = {'family':'serif','color':'blue','size':20}
  font2 = {'family':'serif','color':'darkred','size':15}
  if accent_long_var=='Alemannische Färbung,Schweizer Standart Deutsch':
    font1 = {'family':'serif','color':'blue','size':13}
    accent_long_var='Alemannische Färbung,\n Schweizer Standart Deutsch'
  
  plt.title(accent_long_var,fontdict  = font1)
  #ax.legend()
  #min([], default="EMPTY")
  ax = sns.barplot(x = 'gender', y = 'accent_Duration_mean_gender', data = dataset_test_ca_validated_tsv_family)

plt.savefig('plotBarDiagramsAccent_gender.png')
# Out:
# ################################## Bar chart: x='accent', y = 'accent_Duration_mean' according to the gender - Accent ='all Accent' ###########################################

# %% [markdown]
# ####**<font color="1497d4">Bar chart: All Accent - Age</font>** **x='accent', y = 'accent_Duration_mean' according to age where Accent ='all Accent'**

# %%
############################## Bar chart: x='accent', y = 'accent_Duration_mean' according to the age - Accent ='all Accent'#######################################
print("################################## Bar chart: x='accent', y = 'accent_Duration_mean' according to the age - Accent ='all Accent' ###########################################")
# def plotBarChartsDurrationageAllAccent():
list_dataset_test_=['at','ca','ch','de_al','de_ni','de','fr','gb','it','ru','us']
list_dataset_test_accent=['Österreichisches Deutsch','Kanadisches Deutsch','Schweizerdeutsch','Alemannische Färbung,Schweizer Standart Deutsch','Niederländisch Deutsch','Deutschland Deutsch',
'Französisch Deutsch','Britisches Deutsch','Italienisch Deutsch','Russisch Deutsch','Amerikanisches Deutsch']

# list_dataset_test_=['at']
# list_dataset_test_accent=['Österreichisches Deutsch']

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# four lists of iterations of twenties and thirties elements
list_twenties=list(map(lambda x:'twenties',list_dataset_test_))
list_thirties=list(map(lambda x:'thirties',list_dataset_test_))
list_fourties=list(map(lambda x:'fourties',list_dataset_test_))
list_fifties=list(map(lambda x:'fifties',list_dataset_test_))



data_1 = {'Accent_short': list_dataset_test_,
'Accent_long': list_dataset_test_accent,'twenties':list_twenties,'thirties':list_thirties,'fourties':list_fourties,'fifties':list_fifties  }
dataset_accent_age = pd.DataFrame(data_1)
############################# 1- reading the dataset ##########################################################



for i in range(0,len(dataset_accent_age)):
  

  accent_short_var=dataset_accent_age['Accent_short'][i]
  accent_long_var=dataset_accent_age['Accent_long'][i]
  age_var_twenties=dataset_accent_age['twenties'][i]
  age_var_thirties=dataset_accent_age['thirties'][i]
  age_var_fourties=dataset_accent_age['fourties'][i]
  age_var_fifties=dataset_accent_age['fifties'][i]

  ##

#########################################################################################################################################################################
########################################################### ages 20 - 30 ################################################################################################
#########################################################################################################################################################################
  # dataset_accent_age=f'dataset_test_{i}'
  # textfile_name=f'test_{i}.txt'
  dataset_test_ca = pd.read_csv(f'test_{accent_short_var}.txt', header=None, names=['audio_filepath','text','duration'])
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  
  # dataset_test_ca=f'dataset_test_{i}'
  # extract the numeric values of the durations from the third Column and store it in a new column called
  dataset_test_ca['duration_numeric'] = dataset_test_ca['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
  dataset_test_ca['duration_numeric'] =dataset_test_ca['duration_numeric'].div(10)
  # extract the numeric values of the durations from the third Column and store it in a new column called 
  #dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

  dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].str[-13:-5]



  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
  dataset_test_ca['audio_filepath_numeric']=dataset_test_ca['audio_filepath_numeric'].astype('int')

#########***********************************

  ############################ 3-A Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_twenties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_twenties)].index, inplace=True)


  ############################ 3-B Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_twenties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  

  

  ############################# 3- Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_twenties age and accent_long_var rows #############################
  # dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_twenties) |
  # (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  #dataset_validated_tsv



  ############################# 4- Merge using audio_filepath_numeric column ##################################
  ####################5-calculate the Mean of duration when the age is twenties###########################
  dataset_test_ca_validated_tsv_twenties=pd.merge(dataset_test_ca,dataset_validated_tsv)
  dataset_test_ca_validated_tsv_twenties['age']=dataset_test_ca_validated_tsv_twenties['age'].astype("string")
  dataset_test_ca_validated_tsv_twenties['accent_Duration_mean_age']=np.mean(dataset_test_ca_validated_tsv_twenties['duration_numeric'])


  # ############################ 6- reading the dataset to make the calculations of the age thirties #################
  # ############################ 7- extract the audio_filepath number and change them to integer  #################### 
  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
   
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')

# print('##'*20,accent_long_var,'##'*60)
# print(dataset_validated_tsv)

  # ############################# 8-A Drop all NaN age and NaN Accent values, and show only the thirties -->>age_var_thirties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_thirties)].index, inplace=True)

############################ 8-B Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_thirties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)

# print('##'*20,accent_long_var,'##'*60)
# dataset_validated_tsv

 
  ############################# 9- Merge using audio_filepath_numeric column ##################################
  dataset_test_ca_validated_tsv_thirties=pd.merge(dataset_test_ca,dataset_validated_tsv)
  dataset_test_ca_validated_tsv_thirties['age']=dataset_test_ca_validated_tsv_thirties['age'].astype("string")


  #################### 10- calculate the Mean of duration when the age is thirties###########################
  dataset_test_ca_validated_tsv_thirties['accent_Duration_mean_age']=np.mean(dataset_test_ca_validated_tsv_thirties['duration_numeric'])
  #dataset_test_ca_validated_tsv_thirties
  ###### add/append the upper dataset dataset_test_ca_validated_tsv_twenties to the lower dataset dataset_test_ca_validated_tsv_thirties###########################
  ###### and call the result dataset_test_ca_validated_tsv_20_30
  ####>>>>>>>dataset_test_ca_validated_tsv_20_30=dataset_test_ca_validated_tsv_twenties.append(dataset_test_ca_validated_tsv_thirties)

#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_test_ca_validated_tsv_twenties.empty and not dataset_test_ca_validated_tsv_thirties.empty:
    dataset_test_ca_validated_tsv_20_30=dataset_test_ca_validated_tsv_twenties.append(dataset_test_ca_validated_tsv_thirties)
  elif dataset_test_ca_validated_tsv_twenties.empty and not dataset_test_ca_validated_tsv_thirties.empty:
    dataset_test_ca_validated_tsv_20_30=dataset_test_ca_validated_tsv_thirties
  elif dataset_test_ca_validated_tsv_thirties.empty and not dataset_test_ca_validated_tsv_twenties.empty:
    dataset_test_ca_validated_tsv_20_30=dataset_test_ca_validated_tsv_twenties
  else:
    data_3={'age':['twenties','thirties'],'accent_Duration_mean_age':[0,0]}
    dataset_test_ca_validated_tsv_20_30=pd.DataFrame(data_3)


#########################################################################################################################################################################
########################################################### ages 40 - 50 ################################################################################################
#########################################################################################################################################################################



  dataset_test_ca = pd.read_csv(f'test_{accent_short_var}.txt', header=None, names=['audio_filepath','text','duration'])
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  

  # extract the numeric values of the durations from the third Column and store it in a new column called
  dataset_test_ca['duration_numeric'] = dataset_test_ca['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
  dataset_test_ca['duration_numeric'] =dataset_test_ca['duration_numeric'].div(10)
  # extract the numeric values of the durations from the third Column and store it in a new column called audio_filepath_numeric
  dataset_test_ca['audio_filepath_numeric'] = dataset_test_ca['audio_filepath'].str[-13:-5]



  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
  dataset_test_ca['audio_filepath_numeric']=dataset_test_ca['audio_filepath_numeric'].astype('int')


  ############################ 3-A Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fourties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_fourties)].index, inplace=True)


  ############################ 3-B Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fourties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  

  

  ############################# 3- Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fourties age and accent_long_var rows #############################
  # dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_fourties) |
  # (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  #dataset_validated_tsv



  ############################# 4- Merge using audio_filepath_numeric column ##################################
  ####################5-calculate the Mean of duration when the age is fourties###########################
  dataset_test_ca_validated_tsv_fourties=pd.merge(dataset_test_ca,dataset_validated_tsv)
  dataset_test_ca_validated_tsv_fourties['age']=dataset_test_ca_validated_tsv_fourties['age'].astype("string")
  dataset_test_ca_validated_tsv_fourties['accent_Duration_mean_age']=np.mean(dataset_test_ca_validated_tsv_fourties['duration_numeric'])


  # ############################ 6- reading the dataset to make the calculations of the age fifties #################
  # ############################ 7- extract the audio_filepath number and change them to integer  #################### 
  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')

# print('##'*20,accent_long_var,'##'*60)
# print(dataset_validated_tsv)

  # ############################# 8-A Drop all NaN age and NaN Accent values, and show only the fifties -->>age_var_fifties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_fifties)].index, inplace=True)

############################ 8-B Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fifties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)

# print('##'*20,accent_long_var,'##'*60)
# dataset_validated_tsv

 
  ############################# 9- Merge using audio_filepath_numeric column ##################################
  dataset_test_ca_validated_tsv_fifties=pd.merge(dataset_test_ca,dataset_validated_tsv)
  dataset_test_ca_validated_tsv_fifties['age']=dataset_test_ca_validated_tsv_fifties['age'].astype("string")


  #################### 10- calculate the Mean of duration when the age is fifties###########################
  dataset_test_ca_validated_tsv_fifties['accent_Duration_mean_age']=np.mean(dataset_test_ca_validated_tsv_fifties['duration_numeric'])
  #dataset_test_ca_validated_tsv_fifties
  ###### add/append the upper dataset dataset_test_ca_validated_tsv_fourties to the lower dataset dataset_test_ca_validated_tsv_fifties###########################
  ###### and call the result dataset_test_ca_validated_tsv_40_50
  ####>>>>>>>dataset_test_ca_validated_tsv_40_50=dataset_test_ca_validated_tsv_fourties.append(dataset_test_ca_validated_tsv_fifties)

#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_test_ca_validated_tsv_fourties.empty and not dataset_test_ca_validated_tsv_fifties.empty:
    dataset_test_ca_validated_tsv_40_50=dataset_test_ca_validated_tsv_fourties.append(dataset_test_ca_validated_tsv_fifties)
  elif dataset_test_ca_validated_tsv_fourties.empty and not dataset_test_ca_validated_tsv_fifties.empty:
    dataset_test_ca_validated_tsv_40_50=dataset_test_ca_validated_tsv_fifties
  elif dataset_test_ca_validated_tsv_fifties.empty and not dataset_test_ca_validated_tsv_fourties.empty:
    dataset_test_ca_validated_tsv_40_50=dataset_test_ca_validated_tsv_fourties
  else:
    data_3={'age':['fourties','fifties'],'accent_Duration_mean_age':[0,0]}
    dataset_test_ca_validated_tsv_40_50=pd.DataFrame(data_3)

#########################################################################################################################################################################
########################################################### merge all ages: 20-30 with 40 - 50 ########################################################################## 
#########################################################################################################################################################################
  ###>>>>>>>>dataset_test_ca_validated_tsv_all_ages=dataset_test_ca_validated_tsv_20_30.append(dataset_test_ca_validated_tsv_40_50)


#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_test_ca_validated_tsv_20_30.empty and not dataset_test_ca_validated_tsv_40_50.empty:
    dataset_test_ca_validated_tsv_all_ages=dataset_test_ca_validated_tsv_20_30.append(dataset_test_ca_validated_tsv_40_50)
  elif dataset_test_ca_validated_tsv_20_30.empty and not dataset_test_ca_validated_tsv_40_50.empty:
    dataset_test_ca_validated_tsv_all_ages=dataset_test_ca_validated_tsv_40_50
  elif dataset_test_ca_validated_tsv_40_50.empty and not dataset_test_ca_validated_tsv_20_30.empty:
    dataset_test_ca_validated_tsv_all_ages=dataset_test_ca_validated_tsv_20_30
  else:
    data_3={'age':['fourties','fifties'],'accent_Duration_mean_age':[0,0]}
    dataset_test_ca_validated_tsv_all_ages=pd.DataFrame(data_3)



  ################### 11- plot the dataset_test_ca_validated_tsv_family in Bar Chart #######################

  figure_duriation_distribution_accent=plt.figure(12,figsize=(25,25))  
  #plt.subplots(figure's number per column,figure's number per row)

  # Sup_plot_position=f'dataset_test_{i}'

  # Sup_plot_position=Sup_plot_position.astype(int)
  ax_duriation_distribution_accent_at=figure_duriation_distribution_accent.add_subplot(3,4,i+1)
  font1 = {'family':'serif','color':'blue','size':20}
  font2 = {'family':'serif','color':'darkred','size':15}
  if accent_long_var=='Alemannische Färbung,Schweizer Standart Deutsch':
    font1 = {'family':'serif','color':'blue','size':13}
    accent_long_var='Alemannische Färbung,\n Schweizer Standart Deutsch'
  plt.title(accent_long_var,fontdict  = font1)
  #ax.legend()
  ax = sns.barplot(x = 'age', y = 'accent_Duration_mean_age', data = dataset_test_ca_validated_tsv_all_ages)
plt.savefig('plotBarDiagramsAccent_age.png')
# Out:
# ################################## Bar chart: x='accent', y = 'accent_Duration_mean' according to the age - Accent ='all Accent' ###########################################

# %% [markdown]
# ###**<font color="1497d4">Bar charts Word Error Rate's Accent  </font>**

# %% [markdown]
# ####**<font color="1497d4">Bar chart: </font>** **x='accent', y = 'wer_accent_mean' according to Word Error Rate Accent ='all Accent'**

# %%
############################################################################################################################################ 
####################Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate Accent ='all Accent'##########################
############################################################################################################################################ 

accent_long_var='Alemannische Färbung,Schweizer Standart Deutsch'

 
###########################################################################
# dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb'],
#                                           'accent_long':['Österreichisches Deutsch','Britisches Deutsch'],
#                                         'test_accent_txt':['test_at.txt','test_gb.txt']})

###########################################################################


dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb','it','de_al','fr','de_ni','ch','de','us','ca','ru'],
                                          'accent_long':['Österreichisches Deutsch','Britisches Deutsch','Italienisch Deutsch','Alemannische Färbung,Schweizer Standart Deutsch',
'Französisch Deutsch','Niederländisch Deutsch','Schweizerdeutsch','Deutschland Deutsch','Amerikanisches Deutsch','Kanadisches Deutsch','Russisch Deutsch'],
                                        'test_accent_txt':['test_at.txt','test_gb.txt','test_it.txt','test_de_al.txt','test_fr.txt','test_de_ni.txt','test_ch.txt',
               'test_de.txt','test_us.txt','test_ca.txt','test_ru.txt']})

##############################################################################################################

list_accent_all_wer_mean_result=[]
dataset_accent_all_wer_mean_result=pd.DataFrame(list_accent_all_wer_mean_result,columns=['accent_short','accent_long','test_accent_txt','wer_accent_mean'])
##############################################################################################################


for i in range(len(dataset_results_json_accent)):
  dataset_results_json = pd.read_json('results.json')

  ###################################################################################################
  ###################Convert Json Index to column contents in dataframe #############################
  ###################################################################################################

  dataset_results_json['audio_filepath'] = dataset_results_json.index

  dataset_results_json['audio_filepath_numeric'] = dataset_results_json['audio_filepath'].str[-12:-4]
  
  ###>>> dataset_results_json_audio_filepath is the dataset_results_json DataFrame with the audio_filepath as index
  dataset_results_json_audio_filepath=dataset_results_json.reindex(dataset_results_json['audio_filepath_numeric'])

  # filling up the ['audio_filepath_numeric'] Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath['audio_filepath_numeric']=np.where(dataset_results_json['audio_filepath_numeric']!=np.NaN,dataset_results_json['audio_filepath_numeric'],'0000')


  # filling up the Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]]=np.where(dataset_results_json[dataset_results_json_accent.test_accent_txt[i]]!=np.NaN,
                                                                                               dataset_results_json[dataset_results_json_accent.test_accent_txt[i]],'000')
  
  # dataset_results_json_audio_filepath['accent_long']=np.where(dataset_results_json['accent_long']!=np.NaN,dataset_results_json['accent_long'],'000')
  # dataset_results_json_audio_filepath['test_accent_txt']=np.where(dataset_results_json['test_accent_txt']!=np.NaN,dataset_results_json['test_accent_txt'],'000')
 

 
  #################################Extract and calculate the wer_accent_numeric########################################
  # drop the NaN values of the accent "test_accent_txt"  by each one 
  dataset_results_json_audio_filepath.drop(dataset_results_json_audio_filepath[ (dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].isna())].index, inplace=True)

  
  # extract the numeric values of the WER durations from the accent Column and store it in a new column called wer_accent_numeric
 
  dataset_results_json_audio_filepath['wer_accent_numeric'] = dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)


  #### calculate the mean of the WER for each accent  
  # dataset_results_json_audio_filepath['wer_accent_mean'] = np.where(dataset_results_json_audio_filepath['wer_accent_numeric']!=np.NaN,np.mean(dataset_results_json_audio_filepath['wer_accent_numeric']), '000')
  # dataset_results_json_audio_filepath['wer_accent_mean']=dataset_results_json_audio_filepath['wer_accent_mean'].astype(float)

  # dataset_results_json_audio_filepath['wer_accent_mean']=dataset_results_json_audio_filepath['wer_accent_mean'].div(10e+14/1.93)

  # dataset_results_json_audio_filepath['wer_accent_mean'] = np.where(dataset_results_json_audio_filepath['wer_accent_numeric']!=np.NaN,np.round(dataset_results_json_audio_filepath['wer_accent_mean'],9), '000')


  # to store the mean of each WER Accents in var from the DataFrame dataset_results_json_audio_filepath
  # wer_accent_mean_var=dataset_results_json_audio_filepath['wer_accent_mean']
  wer_accent_mean_var=dataset_results_json_audio_filepath.mean(axis=0, skipna=None, level=None, numeric_only=True)
  
  # wer_accent_mean_var=wer_accent_mean_var/(10e+14/1.93)

  wer_accent_mean_var=wer_accent_mean_var
  wer_accent_mean_var =  wer_accent_mean_var.to_string()
  wer_accent_mean_var=wer_accent_mean_var[22:25]
 
  # print('*'*60,type(wer_accent_mean_var))
  # print('*'*60,wer_accent_mean_var)
  ## prepare the last DataFrame which contains of 3 coulmns accent and wer_accent_mean


  dataset_accent_all_wer_mean_result = dataset_accent_all_wer_mean_result.append({'accent_short': f'{dataset_results_json_accent.accent_short[i]}','accent_long': f'{dataset_results_json_accent.accent_long[i]}',
  'test_accent_txt': f'{dataset_results_json_accent.test_accent_txt[i]}','wer_accent_mean': f'{wer_accent_mean_var}'}, ignore_index=True)
  dataset_accent_all_wer_mean_result['wer_accent_mean']=dataset_accent_all_wer_mean_result['wer_accent_mean'].astype(float)



################################## Accent AT ###########################################
# position of the figure and figure's size 
figure_duriation_distribution_accent=plt.figure(12,figsize=(12,12))  
#plt.subplots(figure's number per column,figure's number per row)
# ax_duriation_distribution_accent_at=figure_duriation_distribution_accent.add_subplot(3,4,i+1)


# plt.xlabel("Speaker's accent - Austria")
# plt.ylabel("Duriation Distribution of Audiofiles")
# plt.plot(dataset_results_json['accent_Duration_mean'],dataset_results_json['audio_filepath_numeric'], lw=3, ms=20)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
# if accent_long_var=='Alemannische Färbung,Schweizer Standart Deutsch':
  #font1 = {'family':'serif','color':'blue','size':13}
  # font2 = {'family':'serif','color':'darkred','size':10}
#   accent_long_var='Alemannische Färbung,\n Schweizer Standart Deutsch'

# to short the long accent which called Alemannische Färbung,Schweizer Standart Deutsch
dataset_accent_all_wer_mean_result['accent_long']=np.where(dataset_accent_all_wer_mean_result['accent_long']=='Alemannische Färbung,Schweizer Standart Deutsch', 'Alemannische**Standart Deutsch',dataset_accent_all_wer_mean_result['accent_long'])
plt.title('Word Error Rate mean for all Accents',fontdict  = font1)

# if accent_long_var=='Alemannische Färbung,Schweizer Standart Deutsch':
#   accent_long_var='Alemannische ** Standart Deutsch'
ax = sns.barplot(x = 'accent_long' , y = 'wer_accent_mean', data = dataset_accent_all_wer_mean_result)

plt.xticks(rotation=70)
  
plt.tight_layout()
plt.savefig('plotBarDiagrams_Accent_WER.png')

# %%
dataset_accent_all_wer_mean_result
# Out:
#    accent_short                     accent_long test_accent_txt  \
# 0            at        Österreichisches Deutsch     test_at.txt
# 1            gb              Britisches Deutsch     test_gb.txt
# 2            it             Italienisch Deutsch     test_it.txt
# 3         de_al  Alemannische**Standart Deutsch  test_de_al.txt
# 4            fr             Französisch Deutsch     test_fr.txt
# 5         de_ni          Niederländisch Deutsch  test_de_ni.txt
# 6            ch                Schweizerdeutsch     test_ch.txt
# 7            de             Deutschland Deutsch     test_de.txt
# 8            us          Amerikanisches Deutsch     test_us.txt
# 9            ca             Kanadisches Deutsch     test_ca.txt
# 10           ru                Russisch Deutsch     test_ru.txt
#
#     wer_accent_mean
# 0               1.7
# 1               1.9
# 2               1.1
# 3               1.1
# 4               2.5
# 5               3.5
# 6               2.6
# 7               1.8
# 8               2.2
# 9               3.7
# 10              2.3

# %%
dataset_results_json = pd.read_json('results.json')
dataset_results_json['audio_filepath'] = dataset_results_json.index

dataset_results_json['audio_filepath_numeric'] = dataset_results_json['audio_filepath'].str[-12:-4].astype(float)

# %%
dataset_results_json.mean(numeric_only=None)
# Out:
# <ipython-input-47-447e8923c74c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset_results_json.mean(numeric_only=None)
# audio_filepath_numeric    2.168664e+07
# dtype: float64

# %%
############################################################################################################################################ 
####################Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate Accent ='all Accent'##########################
############################################################################################################################################ 

accent_long_var='Alemannische Färbung,Schweizer Standart Deutsch'

 
###########################################################################
# dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb'],
#                                           'accent_long':['Österreichisches Deutsch','Britisches Deutsch'],
#                                         'test_accent_txt':['test_at.txt','test_gb.txt']})

###########################################################################


dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb','it','de_al','fr','de_ni','ch','de','us','ca','ru'],
                                          'accent_long':['Österreichisches Deutsch','Britisches Deutsch','Italienisch Deutsch','Alemannische Färbung,Schweizer Standart Deutsch',
'Französisch Deutsch','Niederländisch Deutsch','Schweizerdeutsch','Deutschland Deutsch','Amerikanisches Deutsch','Kanadisches Deutsch','Russisch Deutsch'],
                                        'test_accent_txt':['test_at.txt','test_gb.txt','test_it.txt','test_de_al.txt','test_fr.txt','test_de_ni.txt','test_ch.txt',
               'test_de.txt','test_us.txt','test_ca.txt','test_ru.txt']})

##############################################################################################################

list_accent_all_wer_mean_result=[]
dataset_accent_all_wer_mean_result=pd.DataFrame(list_accent_all_wer_mean_result,columns=['accent_short','accent_long','test_accent_txt','wer_accent_mean'])
##############################################################################################################


for i in range(len(dataset_results_json_accent)):
  dataset_results_json = pd.read_json('results.json')

  ###################################################################################################
  ###################Convert Json Index to column contents in dataframe #############################
  ###################################################################################################

  dataset_results_json['audio_filepath'] = dataset_results_json.index

  dataset_results_json['audio_filepath_numeric'] = dataset_results_json['audio_filepath'].str[-12:-4]
  
  ###>>> dataset_results_json_audio_filepath is the dataset_results_json DataFrame with the audio_filepath as index
  dataset_results_json_audio_filepath=dataset_results_json.reindex(dataset_results_json['audio_filepath_numeric'])

  # filling up the ['audio_filepath_numeric'] Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath['audio_filepath_numeric']=np.where(dataset_results_json['audio_filepath_numeric']!=np.NaN,dataset_results_json['audio_filepath_numeric'],'0000')


  # filling up the Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]]=np.where(dataset_results_json[dataset_results_json_accent.test_accent_txt[i]]!=np.NaN,
                                                                                               dataset_results_json[dataset_results_json_accent.test_accent_txt[i]],'000')
  
  # dataset_results_json_audio_filepath['accent_long']=np.where(dataset_results_json['accent_long']!=np.NaN,dataset_results_json['accent_long'],'000')
  # dataset_results_json_audio_filepath['test_accent_txt']=np.where(dataset_results_json['test_accent_txt']!=np.NaN,dataset_results_json['test_accent_txt'],'000')
 

 
  #################################Extract and calculate the wer_accent_numeric########################################
  # drop the NaN values of the accent "test_accent_txt"  by each one 
  dataset_results_json_audio_filepath.drop(dataset_results_json_audio_filepath[ (dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].isna())].index, inplace=True)

  
  # extract the numeric values of the WER durations from the accent Column and store it in a new column called wer_accent_numeric
 
  dataset_results_json_audio_filepath['wer_accent_numeric'] = dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

  # print([dataset_results_json_audio_filepath[i] for i in dataset_results_json_accent.test_accent_txt],'*'*60, [dataset_results_json_audio_filepath.mean()])

# %%
dataset_results_json_audio_filepath
# Out:
#                        test_at.txt test_gb.txt test_it.txt test_de_al.txt  \
# audio_filepath_numeric
# 18520278                       NaN         NaN         NaN            NaN
# 26888041                       NaN         NaN         NaN            NaN
# 27399033                       NaN         NaN         NaN            NaN
# 27399034                       NaN         NaN         NaN            NaN
# 27399035                       NaN         NaN         NaN            NaN
# ...                            ...         ...         ...            ...
# 17645865                       NaN         NaN         NaN            NaN
# 17645866                       NaN         NaN         NaN            NaN
# 18862913                       NaN         NaN         NaN            NaN
# 18862914                       NaN         NaN         NaN            NaN
# 18862915                       NaN         NaN         NaN            NaN
#
#                        test_fr.txt test_de_ni.txt test_ch.txt test_de.txt  \
# audio_filepath_numeric
# 18520278                       NaN            NaN         NaN         NaN
# 26888041                       NaN            NaN         NaN         NaN
# 27399033                       NaN            NaN         NaN         NaN
# 27399034                       NaN            NaN         NaN         NaN
# 27399035                       NaN            NaN         NaN         NaN
# ...                            ...            ...         ...         ...
# 17645865                       NaN            NaN         NaN         NaN
# 17645866                       NaN            NaN         NaN         NaN
# 18862913                       NaN            NaN         NaN         NaN
# 18862914                       NaN            NaN         NaN         NaN
# 18862915                       NaN            NaN         NaN         NaN
#
#                        test_us.txt test_ca.txt  \
# audio_filepath_numeric
# 18520278                       NaN         NaN
# 26888041                       NaN         NaN
# 27399033                       NaN         NaN
# 27399034                       NaN         NaN
# 27399035                       NaN         NaN
# ...                            ...         ...
# 17645865                       NaN         NaN
# 17645866                       NaN         NaN
# 18862913                       NaN         NaN
# 18862914                       NaN         NaN
# 18862915                       NaN         NaN
#
#                                                               test_ru.txt  \
# audio_filepath_numeric
# 18520278                {'reference': 'was solls ich bin bereit', 'hyp...
# 26888041                {'reference': 'wenn nicht dann legt man sie ir...
# 27399033                {'reference': 'die stadt ist ein wechsel aus h...
# 27399034                {'reference': 'diesen schlussfolgerungen fehle...
# 27399035                {'reference': 'ursprünglich gehörte das anwese...
# ...                                                                   ...
# 17645865                {'reference': 'sie kramte in ihrer tasche', 'h...
# 17645866                {'reference': 'libreville ist die hauptstadt v...
# 18862913                {'reference': 'das ramponierte image haben sie...
# 18862914                {'reference': 'er macht einen unterforderten e...
# 18862915                {'reference': 'mit der kippe sind sie für ihr ...
#
#                        audio_filepath audio_filepath_numeric  \
# audio_filepath_numeric
# 18520278                          NaN               18520278
# 26888041                          NaN               26888041
# 27399033                          NaN               27399033
# 27399034                          NaN               27399034
# 27399035                          NaN               27399035
# ...                               ...                    ...
# 17645865                          NaN               17645865
# 17645866                          NaN               17645866
# 18862913                          NaN               18862913
# 18862914                          NaN               18862914
# 18862915                          NaN               18862915
#
#                         wer_accent_numeric
# audio_filepath_numeric
# 18520278                                 0
# 26888041                                 0
# 27399033                  9090909090909000
# 27399034                                 0
# 27399035                 33333333333333304
# ...                                    ...
# 17645865                                 0
# 17645866                                 0
# 18862913                                 0
# 18862914                                 0
# 18862915                                 0
#
# [973 rows x 14 columns]

# %%
import json


if __name__ == "__main__":

  results = json.load(open('/content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/results.json'))
  for test_file in results:
    ref_lens = [len(v["reference"].split(" ")) for v in results[test_file].values()]
    edits = [int(v["wer"] * ref_lens[i]) for i, v in enumerate(results[test_file].values())]
    print(test_file, round(sum(edits) / sum(ref_lens) * 100, 2))
# Out:
# test_at.txt 2.84
# test_gb.txt 5.08
# test_it.txt 2.25
# test_de_al.txt 2.06
# test_fr.txt 5.27
# test_de_ni.txt 5.68
# test_ch.txt 4.24
# test_de.txt 3.2
# test_us.txt 5.6
# test_ca.txt 5.0
# test_ru.txt 4.5

# %%
import json
if __name__ == "__main__":
  results = json.load(open('results.json'))
  for test_file in results:

    ### test_file -->> test_at.txt, test_gb.txt,..,test_ru.txt

    ### results[test_file].values() -->> print test_at.txt dict_values([{'reference': 'er ist nach eustache de saint pierre der bekannteste der gruppe', ), then  print test_gb.txt dict_values()....
    ref_lens = [len(v["reference"].split(" ")) for v in results[test_file].values()]
    [print(v["reference"]) for v in results[test_file].values()]
    # ### v["reference"] -->> print the V / Values/text of "reference"
    # ### ref_lens  ref_lens = [len(v["reference"].split(" ")) -->> print the len /the number of the words (which seperated by a space " ") as th efollowing exp
   

    # #################################################################################################
    # # txt="Selam,#The#last#Prophet#after#Juses#son#of#Maryim#PBUT#is#Prophet#Muhammed#PBUH,#He#is#an#amazing#Perfect#Person"

    # # # setting the maxsplit parameter to 1, will return a list with 2 elements!
    # # x = txt.split("#",5)
    # # print(x)
    # # print('**'*60)
    # # print(len(x)) 
    # ##############################################OUTput##############################################
    # # ['Selam,', 'The', 'last', 'Prophet', 'after', 'Juses#son#of#Maryim#PBUT#is#Prophet#Muhammed#PBUH,#He#is#an#amazing#Perfect#Person']
    # # ************************************************************************************************************************
    # # 6
    # #################################################################################################
    # edits = [int(v["wer"] * ref_lens[i]) for i, v in enumerate(results[test_file].values())]
    # print(test_file, round(sum(edits) / sum(ref_lens) * 100, 2))
    # # print(ref_lens)
# Out:
# Streaming output truncated to the last 5000 lines.
# die entwicklungsländer werden hiervon nicht berührt
# der schutzheilige des ortes ist san giovanni battista
# während des zweiten weltkriegs wurde es als zielobjekt für übungen der deutschen luftwaffe benutzt
# nach seiner sportlichen karriere arbeitete er als fernsehmoderator
# der teppich ist voller läuse
# deswegen haben wir die lenkungsgruppe unter vorsitz unseres kollegen joseph daul eingesetzt
# jeder weiß dass wir niemals aufgeben werden
# es ist unsere pflicht auch unsere amerikanischen partner davon zu überzeugen
# diese ganzen logikfehler in der handlung sind doch offensichtlich
# keine form der finanziellen unterstützung sollte als selbstverständlich gelten
# die gewährung von makrofinanzhilfe für albanien findet meine volle zustimmung
# an der dritten hand ist eine lupe mit einer kleinen leuchte befestigt
# vermutlich waren sie bisweilen über die härte der verhandlungen sogar bestürzt
# im zentrum steht die aus und weiterbildung von lehrerinnen und lehrern
# so detailliert können wir darauf leider nicht eingehen
# er gewann vor dem spanier daniel plaza
# von der watt bis zur brandungsseite sind es mit dem fahrrad nur etwa fünfzehn minuten
# sehenswert sind auch das ehemalige fährhaus sowie einige zum schloss gehörende gutshöfe
# sein hobby ist neben dem sport die musik
# auf die dauer konnten diese anlagen jedoch nicht wirtschaftlich betrieben werden
# man darf vor einer darmspiegelung nichts essen
# schauen sie nochmal im protokoll nach
# in mumbai verbreitete sich zunächst panik und unsicherheit
# waschkeller sollten gut belüftet werden damit es nicht zu schimmelbildung kommt
# es gibt eine unmenge an möglichen anordnungen eines schachbretts
# dadurch vervielfacht sich die zahl
# er zückte seine kamera und hielt die bildschirmausgabe auf einem foto fest
# in seinem oberlauf ist er durch viele anstiege gekennzeichnet
# keiner von ihnen würde das monopol je freiwillig aufgeben
# korps versetzt
# udo hat bärbel missverstanden
# näher wird das verfahren durch die geschäftsordnung des bundestags ausgestaltet
# es war sicherlich aufwendig eine solche weinsammlung zusammenzustellen
# ein missglückter fluchtversuch brachte ihn für eine weile in ein straflager
# der rat der union hat bei verschiedenen anlässen seine gesprächsbereitschaft signalisiert
# was sie alles zu rugova gesagt hatten stimmt
# woher soll ich das wissen
# von diesem aussichtspunkt kann man das gesamte tal überblicken
# drei
# wir halten dies für eine vernünftige lösung
# die sahara ist die größte wüste der welt
# die hafenanlagen verteilen sich weiträumig über vancouver und verschiedene angrenzende gemeinden
# bei der wahl setzte er sich deutlich gegen seinen neuseeländischen amtsvorgänger ben sandford durch
# airbus und boeing konkurrieren
# seine egozentrische persönlichkeit macht es mir nicht leicht
# das sind düstere aussichten
# du schienst etwas neben der spur zu sein
# er stellt die verbindung zwischen der realen und der übersinnlichen welt her
# für das briefing bleiben nur zwei minuten zeit
# die kathedrale der gemeinschaft ist geschützt durch eine mauer die genaueres besichtigen verhindert
# der kanton mira erstreckt sich entlang dem südwestrand der provinz carchi
# links zwo drei vier
# es wird in der artillerie zum ausrichten von geschützen und raketen benutzt
# außerdem wird land und forstwirtschaft betrieben
# ich stehe um punkt sieben uhr auf
# durch neue vorwürfe ist die konzernspitze jüngst in bedrängnis geraten
# dies ist kein gerechter krieg
# die zu haftstrafen verurteilten wurden sämtlich zunächst in rabaul später in manus untergebracht
# es war wohl nur ein klingelstreich
# natascha gab schließlich zu dass sie illegal in deutschland wohnt
# die inseln liegen östlich von java
# portugal hat immer so ein losglück
# danach war er bis zu seinem gang in die politik als staatsanwalt tätig
# heute erinnert ein gedenkstein an den ehemaligen ort staufenberg
# der film wurde in der englischen und in der französischen sprachversion gedreht
# großmutter hat immer die besten hausmittel parat
# das beweismaterial ist eindeutig
# unsere robuste technik funktioniert immer sogar im weltraum
# eine dampfbügelstation kann das bügeln erheblich erleichtern
# nächstes wochenende ist zeitumstellung
# zur vernissage kamen rund hundert geladene gäste aus politik und kultur
# ab und zu knackt das holz
# die offizielle version lautet ganz anders
# firefox
# ich sage kein sterbenswörtchen
# also ich verstehe die welt wirklich nicht
# sie verschlimmern nur noch das unglück der trennung
# es wäre daher ein fehler gegen diesen vorschlag zu stimmen
# weitere modelle von simson sind zum beispiel die schwalbe der sperber oder der habicht
# in der schengenzone reicht es wenn man seinen personalausweis dabei hat
# ich erteile der kommission das wort damit sie sich dazu äußern kann
# waschmittel gibt es sowohl flüssig als auch in form eines pulvers
# sie wuchs im rheinmaingebiet auf und studierte dort amerikanistik germanistik und anglistik
# august heißmeyer ist auf dem friedhof in gellersen kreis hamelnpyrmont in einem familiengrab beigesetzt
# und hier kommen die eier in den brutkasten
# blasonierung in rot ein schreitender goldbewehrter silberner greif
# zur sequenzierung sollte die shotgunmethode dienen
# ein zoll unterschied entspricht einem akörbchen zwei zoll einem bkörbchen
# man kann karotten auch roh essen
# daneben will man informationen über das konsumentenverhalten gewinnen
# sie wissen dass der rat ihnen das leben ja häufig schwer macht bei drittstaatenverhandlungen
# drei jahre später schilderte dostojewski dieses ereignis in seinem roman die dämonen
# damit setzen wir uns in der mitteilung auseinander
# aufgrund der hohen einschaltquoten gab der sender fx networks eine zweite staffel in auftrag
# warum gibt es diese werte in china im arabischen bereich so nicht
# welche vor und nachteile haben laser und tintenstrahldrucker
# mit neugier betrachtet jenny das objektiv mit fünfzigfachem zoom
# die bibliothek des kantgymnasiums bietet ein breites angebot an lernmaterialien besonders im fachbereich astronomie
# den antrag muss ich ablehnen so leid es mir tut
# er gehörte zum widerstandskreis um kaiserleuschner
# wie alle knorpelfische besitzen seekatzen keine schwimmblase
# durch die starke bindung des kindes zu seinen eltern ist dieses schema sehr stabil
# danach steht die flüssigkeit in allen ästen gleich hoch
# diese deutung stützte sich auf die skandinavische verwendung des wortes
# verschiedene skizzen veranlassten ihn zu scheinbar unsinnigen und lächerlichen auseinandersetzungen
# kapstadt ist der parlamentssitz von südafrika
# mit der auflösung steigen auch die anforderungen an den fotografen
# das marmeladenglas ist vakuumverschlossen deswegen ploppt es so
# die heizung etwas weniger warm einstellen
# sie war damals ein suffraganbistum des erzbistums santa severina
# die anziehung des mondes erzeugt tiden
# dank seiner freundschaft mit merle travis fand penny schnell anschluss
# auf dem weg liegt ein totes tier
# er war mitarbeiter des dokumentationsarchivs des österreichischen widerstandes
# die luftfeuchtigkeit kommt in der allgemeinen gasgleichung gar nicht vor
# der „brockhaus psychologie“ spricht von gemüt als einem unscharfen begriff
# geladene teilchen können auf mehrere arten energie verlieren
# das wird teuer
# eine gewisse affinität zu diesen themen wird natürlich vorausgesetzt
# auch hier ist die landwirtschaft der wichtigste erwerbszweig
# außerdem wusste herr korte seine beruflichen ziele mit seinen privaten zu verbinden
# auf einer durchschnittlichen tastatur befinden sich mehr keime als auf einer klobrille
# der großteil der weiden entstand außerhalb des heutigen barmbeknord
# mark ist zusammen mit sandra walters miteigentümer der in sydney ansässigen medienproduktionsgesellschaft kapow pictures
# kommst du mit zum essen
# daher ist die firmengeschichte außerordentlich vielfältig und kompliziert
# haben sie schon einmal den keilriemen gewechselt
# was habt ihr denn geguckt
# karel wurde vorsitzender der economic association of paper industry
# der coach sieht großes potenzial in ihm
# was erwartest du
# nach dem ersten weltkrieg begann jürgensen sich verstärkt politisch zu organisieren
# im sammelsurium von alten zeitschriften fand sich auch ein erotikmagazin
# in anlehnung an pünktchen und anton haben sie ihren dackel piefke genannt
# stellvertreterkriege können eine gewaltige wirkung haben besonders auf die örtliche umgebung
# die nächsten veröffentlichungen erreichten mittlere chartpositionen
# kurzum es sind also mutige politische entscheidungen erforderlich
# der distrikt ejisujuaben bildet einen gleichnamigen wahlkreis
# dem werde ich beine machen
# julius fackelte nicht lange sondern machte kurzen prozess mit seinem gegner
# die beförderung von spaltbarem material auf österreichischem staatsgebiet ist untersagt
# notieren sie hier falls sie irgendwelche allergien oder unverträglichkeiten haben
# der abgefaste triumphbogen ist spitzbogig
# eine weitere werbekampagne war „einige nennen es einen speer andere einen pfeil
# eine prise ist so viel wie zwischen zwei finger passt
# das zweite produkt erwies sich als ein großer erfolg
# der tiger schärfte seine krallen
# er hat gerade einen wichtigen kunden deshalb möchte ich ihn nicht stören
# im weiteren sinne ist jähzorn die psychische disposition zu derartigen wutanfällen zu neigen
# als bekannt wurde dass die amerikaner über atomwaffen verfügten verlor diese idee ihre grundlage
# sie liegt im binnenland und grenzt an satakunta päijäthäme kantahäme südösterbotten sowie an varsinaissuomi
# was ist gerade los auf twitter
# ein mann betrat den raum schaltete das licht ein und zog die gardinen zu
# durch die musik gewinnen sie die herzen der kinder
# orange erhält man wenn man rot und gelb mischt
# insgesamt fanden fünf flüge von kapustin jar aus statt
# im rahmen der beratung werden so individuelle problemlösungen erarbeitet
# das event wird in reutlingen stattfinden gab guido bekannt
# wenig später hat paula die abtreibung durchführen lassen
# sie muss ein neues modell für die internationalen beziehungen sein
# dass jemand so gut abschneidet kommt auch nur alle jubeljahre vor
# aufgrund bundesstaatlicher befindlichkeiten lief sein verfahren getrennt vom mansonprozess
# jedoch scheint eine merkliche verrohung der sitten eingetreten zu sein
# seid ihr so eine art schlägertruppe für den guten zweck
# klingt moralisch einwandfrei
# die kanarischen inseln gehören zu spanien
# dies ist unhaltbar
# in diesen fällen entstehen aber sehr viel mehr brutzellen
# gleich vier schlepper bugsieren den containerfrachter zu seinem liegeplatz
# blankenburg unterschrieb als vertreter des leiters für das nichtärztliche personal viktor brack mit „brenner“
# der see kann auf einem gut ausgebauten spazierweg umrundet werden
# dili ist die hauptstadt von osttimor
# sie liegt in der comarca anoia
# der ruppiner see ist das wasserreservoir für das rhinluch
# natürlich erlangt die präventionskultur hier einen neuen sinn und eine neue bedeutung
# so geht auch nichts daneben
# dennoch halte ich es für ein riskantes unterfangen
# spätestens wenn einer am boden liegt hört man auf
# zement ist nur das bindemittel im beton
# und das ist was die frauen und männer in europa brauchen
# als die stadtmauern errichtet wurden hieß es dass sie unbezwingbar seien
# den osmanischen bräuchen wohnt ein zauber inne
# rabat ist die hauptstadt von marokko
# langmuirblodgettschichten sind nach irving langmuir und katherine blodgett benannt
# es ist einfacher eine mehrheitliche übereinstimmung herzustellen als einen konsensus zu erreichen
# diese fachleute sind schüler oder kleine schülergruppen
# es handelt sich um kolleginnen und kollegen aus drei mitgliedstaaten
# anschließend fließt die flüssigkeit in diese kammer wo sie eingedampft wird
# diese erwerbungen lagen auf der älteren linie der vertikalen konzentration
# was heißt das auf badisch
# in von schwarz und silber geviertem schild ein roter balken
# die säule wechselte öfter den standort um den straßenverkehr nicht zu behindern
# weil die tram auch auf der straße fährt hat sie nur zwei scheinwerfer
# das waren noch zeiten als man datenträger mit einem streifen tesafilm wieder reparieren konnte
# sie soll nicht die möglichkeit haben mit schutzklauseln schnell und unbürokratisch einzugreifen
# maseru ist die hauptstadt von lesotho
# das können wir nicht billigen
# nein
# später wurde die stadt an anderer stelle wieder errichtet
# in der lokalpolitik war er dabei auch weiterhin aktiv
# wie sieht es mit der cpuauslastung aus
# koltschak entstammte einer offiziersfamilie
# er wurde dann mit der verteidigung finnlands gegen die russischen truppen beauftragt
# sie kreisen schon die ganze zeit um den kutter
# zu oft kippten stramm stehende offiziere in der vergangenheit einfach um
# von ihren zwei kindern starb eines frühzeitig
# hat sich jetzt jeder in die liste eingetragen
# wir freuen uns auf diese arbeit
# gestern zeigte das barometer einen maximalen ausschlag
# die schriftzüge sind rot umrandet die schrift selbst schwarz auf weißem grund
# nach meinen informationen soll er dem in genf verabschiedeten text entsprechen
# couscous oder kuskus hat sich auch bei uns etabliert
# guck mal wie knuffig
# dieses schwere pony eignete sich jedoch nicht als reitpferd
# koste es was es wolle
# die vier hauptakteure werden in dem papier namentlich genannt
# nach einführung des indirekten schusses wurde diese art der kampfführung aufgegeben
# karla ist völlig hin und weg
# neben der bürgermeisterin war auch der künstler anwesend
# da haben wir den salat
# es ist unmöglich den horizont zu erreichen
# und er sah darin den versuch diese frage der parlamentarischen kontrolle entziehen zu wollen
# dort aber wo natürliche landschaften verändert werden sollte vorsicht geboten sein
# wir befinden uns wahrscheinlich vor einer entscheidenden schwelle
# diese fragen muss die kommission konkret beantworten
# am besten elemente von all dem
# gähnen ist auch übers telefon ansteckend
# zu diesem speziellen thema haben wir im februar dieses jahres einen bericht angenommen
# das moment berechnet sich als kreuzprodukt von radius und kraft
# die zweite alternative besteht in der auswahl eines anderen verkehrsträgers für den güterverkehr
# die abgeschnittenen äste hatten sie zuvor alle durch den häcksler gezogen
# indes empfand er den demokratischen aufbau der partei als belastend
# das veröffentlichte bulletin der kgl
# das ist halt der unterschied zwischen theorie und praxis
# kaputte hemden sind prädestiniert dafür sie im winter zu tragen wenn man sowieso etwas anderes darüber an hat
# vorsitzender richter war kurt ohnesorge und max jäger der erste staatsanwalt
# hierbei stellt der zweite akt eine umkehrung des ersten aktes dar
# den trecker hat er volle pulle gegen die wand gefahren
# insgesamt ist die art recht selten nur in einzelnen regionen häufig
# die steilste strecke des intercityexpresses führt durch geislingen an der steige
# ein punkt der für mich grundlegend ist sollte überdacht werden
# nervös rutscht eugen auf seinem stuhl hin und her
# zusammengefasst ist mein job meinen job abzuschaffen
# atome können moleküle bilden
# seit seiner kindheit hat er seinen spitznamen peppi
# hören sie nun meine persönliche rede an die nation
# schlagen sie zu solange die dinger so billig sind
# seine erste karikatur fertigte er mit zehn jahren an
# der schwede mattias ekström gewann den weltmeisterschaftstitel
# auch das ist ein teil der lösung der umweltproblematik im zusammenhang mit dem klimaschutz
# der sender hat seine lizenz von der landesanstalt für medien nordrheinwestfalen
# die oberen blattspreiten sind eher lanzettförmig bis linearlanzettförmig
# ich möchte den fall abd alnashiri hervorheben
# liebe kommission mach nur dort gesetze wo es im neuen arbeitsprogramm notwendig ist
# die amtssprache im iran ist persisch
# über und unter der inschrift sind jeweils ornamente zu sehen
# es ist wahnsinnig schwierig die helix unbeschädigt um den stift zu friemeln
# die anderen episoden behandeln die quarzuhr das telefon das radio und den videorekorder
# damals wurde die kirche um ein joch nach westen erweitert
# zwei drittel der produktion der international führenden unternehmensgruppe werden exportiert
# ihr vater arbeitete dort als orchestermusiker
# meiner meinung nach sollte sie sich einfach eine andere wohnung suchen
# die einwohner sind traditionell fast ausschließlich katholischer konfession der ort ist nach crostwitz gepfarrt
# es wird also nicht ein bruch gewünscht sondern segen
# man spricht hierbei vom „einkommenseffekt“
# sie hört den song rauf und runter
# dieser vorschlag ist entstanden aus unzähligen gesprächen mit allen beteiligten
# weitere seminare sind in vorbereitung
# heute sind die minen geschlossen
# in diesem fall wäre es kein transatlantikflug
# nach einer lehre als gerber in freiberg wurde er zum kriegsdienst eingezogen
# und dann bekomme ich meine sätze nicht einmal wieder zu gesicht
# anschließend wurden die lücken zwischen den megalithen mit bruchsteinen geschlossen und der cairn aufgeschichtet
# vier
# bisher wurde kein häftling hingerichtet
# was die bundesnetzagentur jetzt einnimmt werden sich die provider von deren kunden zurück holen
# ich mache mir langsam sorgen
# seine mutter war eine schwester von erich von falkenhayn
# notfalls betreiben wir den kamin mit briketts
# du hast es nicht anders gewollt
# eine überregulierung schadet dem verkehrsmarkt
# während des gesamten verhandlungsprozesses blieb die kommission in engem kontakt mit dem parlament
# vorbilder für seine dichtung waren catull und horaz
# hinter dieser wand befindet sich ein hohlraum
# nehmen wir das allseits beliebte beispiel des harmonischen oszillators
# dadurch verdreifachte der stadtbezirk seine fläche die einwohnerzahl verdoppelte sich
# die einzelnen blüten sind kurz gestielt und überragen die blätter kaum oder nur wenig
# das soll doch jeder machen wie er möchte
# midnight movies sind filme aus den verschiedensten genres
# aber auch das parlament hat fehler gemacht
# renko liegt am ochsenweg dem historischen handelsweg von turku nach häme
# irgendwelche pyromanen zündeln am altpapiercontainer
# in der ersten stunde haben wir den schneepflug gelernt
# jeder fachbereich wird von einem geschäftsführer geleitet
# haben wir noch sahne im kühlschrank
# ist die gitarre ordentlich gestimmt
# eine wickelablage muss weich und warm sein
# nazivergleiche sind hier unangebracht
# sie liegen derzeit nur auszugsweise in englischer sprache vor
# seit dieser party ist mein schlafrhythmus ohnehin völlig durcheinander
# bis auf einige instrumentalkompositionen verwendet er in seinem werk den generalbass
# ich predige hier jedoch wie ich weiß vor überzeugten menschen
# wenn ein körper tot in der wohnung liegt wird er bald von insekten befallen
# im gegensatz dazu sind kalksteine und kohle überwiegend autochthon gebildet
# axel hat bei seinem opa im keller ein altes grammophon gefunden
# die fraktion die das dort eingeführt hat war die fraktion von adolf hitler
# bachmayer galt als extrem sadistisch und war aufgrund seiner brutalität bei den häftlingen gefürchtet
# in europa kommen zehn arten vor die in sieben gattungen unterteilt werden
# von eusebius von nikomedia wurde er zum priester geweiht
# es handelt sich um dihydrogenmonoxid
# aufrührerische unterstützer der partei fallen regelmäßig durch politisch motivierte gewaltaktionen auf
# nach der überlieferung herrscht während des jahres in rom eine große hungersnot
# daneben widmet er einen großen teil seiner zeit dem liedgesang
# damit war die grundlage geschaffen impulse über weite strecken zu übertragen
# sie war eine garnisonsstadt der fremdenlegion
# als standardbeispiel für einen torus wird immer der donut aufgeführt
# wo stehen wir jetzt
# innerhalb von dreissig jahren verdreifachte sich die bevölkerungszahl
# da nur wenige chipsätze unterstützt wurden konnte sich diese technik nicht am markt durchsetzen
# auch wenn die sitznachbarn schon komisch gucken muss man selbstbewusst bleiben
# man merkt dem forum an dass freitag ist
# wo geht es zur sparkasse
# na endlich das ordnungsamt ist da
# es war nicht immer leicht in landshut fuß zu fassen
# den passagieren stehen automaten für snacks und getränke zur verfügung
# noire kommt der fluss vor
# der studienschwerpunkt lag dabei auf mexiko und mittelamerika
# allerdings helfen die steine auch die wärme über nacht abzugeben
# diese anfrage hat absolut nichts mit der auf der tagesordnung stehenden anfrage zu tun
# sie beherrscht die sprachen latein griechisch und chinesisch und nimmt an archäologischen ausgrabungen teil
# der ortsname wurde zu „radowo wielkie“ polonisiert
# gibt es dafür auch eine tastenkombination
# das ist bestimmt nur ein probealarm
# um seinen lebensunterhalt zu finanzieren fuhr er taxi
# könig wilhelm machte ihn zum obristen des regiments
# der zug kam dreizehn minuten zu spät
# die avierzig durchquert das ganze ruhrgebiet von duisburg bis dortmund
# erst danach sollten die sätze hierher kopiert werden
# beim diesjährigen krippenspiel mussten maria und joseph improvisieren weil sie den text nicht gelernt hatten
# danach arbeitete sie als gast am schauspielhaus bochum und am nationaltheater mannheim
# bei einigen fluggesellschaften muss das aufgabegepäck extra bezahlt werden
# im farbsystem werden den farben jeweils zahlenwerte oder alphanumerische werte zugeordnet
# ist wiesbaden hier in der nähe
# dies ist kein thema das die leute von den stühlen reißt
# da meine redezeit vermutlich begrenzt ist will ich ohne umschweife mit meinen ausführungen beginnen
# andere interpretationen gehen vom horn eines steinbocks aus
# welch ein haarsträubender fehler
# seine lehrer waren die bildhauer hermann hahn und karl killer
# was ist in diesem bild zu sehen
# meist gewinnt er diese wetten
# punktgleichheit ist dabei möglich
# nach dem niedersächsischen denkmalschutz ist sie ein kulturdenkmal
# die letzte interaktion war erfolgreich
# vom regen wird das gel in die augen gespült und brennt fürchterlich
# es fühlt sich an als würde man auf zahnfleisch gehen
# kent versuchte in der folge sich mit einem englischsprachigen repertoire zu etablieren
# woher weißt du wo ich wohne
# gesamtrang belegte
# die sonne wird die erde eines tages verschlingen
# eine bedeutende sammlung befindet sich zurzeit im schloss von windsor
# mehr als eine million menschen sind immer noch obdachlos
# finden sie es heraus
# sie ist außerordentlich wichtig
# kultiviert wird pinot noir der hier eher im traditionellen stil ausgebaut wird
# wie hier bereits gesagt wurde steht burundi vor einer neuen katastrophe
# in dreisbach gibt es eine vielbesuchte jugendherberge
# das ist übel sprach der dübel und verschwand in der wand
# wir haben regionale beiräte gebildet
# das ist das haus vom nikolaus
# während der republik wurde das schloss sitz des präsidenten
# danach erholte sie sich in ferney
# zudem spricht sie regelmäßig in hörspiel sowie hörbuchproduktionen
# das größte noch ungelöste problem stellt der schiffbau an der adriaküste dar
# gelöst wird die feststellbremse über einen handhebel
# dies betrifft neu startende studierende quereinsteiger und studierende bei überschreitung der regelstudienzeit
# jonathan hat sich erst kürzlich einen neuen porsche gekauft
# dann bis später hat mich wirklich sehr gefreut sie zu hören
# habt ihr schon ideen welche spracheingabeanwendungen wir entwickeln sollen
# auch international konnten einige erfolge gefeiert werden
# durch unsere heutige zustimmung hat das europäische parlament den jahrelangen bananenkrieg beendet
# im grunde haben wir hier das gleiche in grün
# es ist daher anzunehmen dass bereits bei dieser frühen fledermaus die echoortung ausgebildet war
# weil die kinder offenbar zu viel werbung gesehen hatten malten sie die kühe lila an
# so organisiert man ganz bewusst ausgabenkürzungen auf kosten der landwirte
# ungesättigte fettsäuren sind gesünder werden aber schneller ranzig
# er kam jedoch in beiden turnieren nicht zum einsatz
# die fürstin musste den rechtsweg beschreiten um die auszahlung zu erzwingen
# auch an anderen abenden gibt es in der regel keinen so strengen dresscode
# das angebot gilt nur für kurze zeit
# es muss sich grundlegend etwas ändern
# auch mutige menschen haben angst
# bei cuijk zweigt der maaswaalkanal ab der bei nijmegen den hauptarm des rheins erreicht
# durch die phasenverschiebung können wir sehr hohe blindströme messen
# deshalb ist die evaluierungsklausel die im parlamentsbeschluss vorgesehen ist so wichtig
# außerdem sollte man sich den zeitpunkt notieren
# kurz vor seinem tod spielte er in der theaterproduktion gang of seven
# ständig hast du probleme mit ihm
# irgendwann wird es einfach in sich zusammenstürzen
# es sind meist verholzende pflanzen seltener krautige pflanzen
# nach weiteren tests vor den bermudas begann im august die fahrt in den pazifik
# was machen die an anderen messungen
# sie gähnte herzhaft
# aber der saal bietet eine tolle akustik
# dieser mann hat dem tod ins auge gesehen
# der darauf beruhende rege warenhandel und der weinbau spielten eine bedeutende rolle
# manchmal redest du ein zeug daher
# da hilft nur augen zu machen und immer nach vorne blicken
# die bank hat bereits die initiativen von lissabon in gang gesetzt
# der große bereich der voluminösen und verzierten dächer ist annähernd frei von praktischer nutzung
# die zukunft sieht strahlend aus
# am talent gab es früher eine sägerei
# danke für nichts
# es wurde auch international in italienischer und spanischer ausgabe veröffentlicht
# in der wüste gobi gibt es kein wasser aber viel sand
# seine ausarbeitung sah den bau einer damals neuartigen hubbrücke vor
# es ist dennoch eine nette geste
# dieser antrag wurde nicht weiter verfolgt
# was läuft heute abend im kino
# warum wird diese liste nicht veröffentlicht
# das essen wird kalt
# die berichterstatterin hat über ein kritisches thema nämlich die vergleichende bewertung gesprochen
# es besteht akute verdunkelungsgefahr
# am populärsten ist ihre darstellung der borgkönigin in star trek
# ich muss schon in neumünster aussteigen
# die weißeritz ist ein zufluss der elbe
# ein weiterer name ist cordillera tropical
# praia ist die hauptstadt von kap verde
# wir sind ruiniert
# wir haben alles an textilien was sie sich nur vorstellen können
# kohlenhydrate sind besser als ihr ruf
# über einen zahnriemen oder eine kette ist sie mit der motorwelle verbunden
# du oder ich
# oh entschuldigen sie ich glaube ich habe mich verwählt
# zunächst in bezug auf die kohärenz der anwendung der politik
# isabel fallen die ersten milchzähne aus
# aus anatomischer sicht ist ein schwanz nur die verlängerung der wirbelsäule
# sie alle kennen das von blitzen
# der schalter hat wohl einen wackelkontakt
# sie werden jane doe sein
# der wert einer geldeinheit wird als kaufkraft des geldes bezeichnet
# herr designierter präsident prodi wir sozialdemokratinnen sind enttäuscht
# auf dem helm mit blaugoldenen decken der drache
# wie lange braucht man mit dem fahrrad von aschaffenburg bis speyer
# man darf menschenrechtsverletzungen nicht stillschweigend dulden
# als zeichnung treten gelegentlich hellblaue senkrechte streifen auf die meisten exemplare sind aber ungezeichnet
# frank ist mit der gesamtsituation unzufrieden
# die natur ist schon brutal
# nachbarin schiller nahm die wasserpfeife mit beiden händen entgegen
# der starke einbruch des ölpreises führte zu einem wegfall eines bedeutenden teils der staatseinnahmen
# vielleicht wäre es für alle das beste
# während der angelsächsischen zeit profitierte cambridge von den sehr guten handelswegen innerhalb des stadtgebiets
# von sauer wuchs in wien auf und studierte jura in tübingen und berlin
# es gibt bereits exterritoriale gesetzesvorhaben in vorgerücktem stadium gegen den iran und lybien
# es gibt natürlich auch anlässe
# der bericht ist wasser auf die mühlen der atomkraftgegner
# so fielen umfangreiche erdarbeiten an auch der bau des turms war sehr kostspielig
# wer will schon nach garzweiler
# bist du auf diät
# dieses bild bitte auf den großen monitor projizieren
# du bist nicht fair deine fairness lässt zu wünschen übrig
# diese haben die burgen in entringen gebaut
# hongkong ist wie macau eine sonderverwaltungszone der volksrepublik china
# lieber kurz und zackig als lang und tappig
# weiterhin befinden sich im gebäude wohnungen
# dort wurde er nach nur knapp zwei monaten wegen erfolglosigkeit entlassen
# diese siegel setzte sich dann als wappen der stadt durch
# sie wurde auf dem friedhof von zeuthen in brandenburg begraben
# wartet jungs
# in diesem punkt widersprechen sich die quellen
# am freitag will die geschäftsführung bilanz ziehen
# eine gesundheitsversorgung ist weder materiell noch personell vorhanden rechtsstaatliche institutionen gibt es nicht mehr
# wird es die benennung von fluchthäfen durchsetzen
# ausgrabungen belegen dass der ort seit der wikingerzeit besiedelt ist
# über die schmiedeeiserne brücke führt die district line der london underground
# er gilt auch als pionier des musikalischen genres neoklassischer metal
# die tätigkeit der einrichtung gilt steuerlich stets als gewerbebetrieb
# kann man da einfach so rein
# piel setzte dabei selbst in den gefährlichen szenen keine doubles ein
# er wird wieder ein paar einfaltspinsel über die klinge springen lassen
# daher danke ich dem parlament und dem berichterstatter für die geleistete arbeit
# wenn oleg das nur sehen könnte
# gut ausgestattet zu sein erhöht zumindest seinen coolnessfaktor
# die meisten politiker wollen nicht an die macht um sich für eine sache einzusetzen
# hat jemand eine frage zur vorlesung
# mit ihr lebte er zurückgezogen in einem haus in der nähe von skara
# gemeinsam mit der redaktion sehen sie die mondlandung von neil armstrong
# dieser belehnte damit den grafen johann von oldenburg
# france wuchs mit dem aushelfen auf rennstrecken auf
# viel mehr wege gibt es sie zu verlassen
# ich glaube ich stehe im wald
# das ist die wirkliche frage
# ob sie das schaffen werden stellt waldemar das vorhaben infrage
# sie müssen die leitsätze für die zusammenarbeit der mitgliedstaaten innerhalb der union sein
# mit dem fernglas kann man oft seehunde auf dieser sandbank sehen
# sie führen von tübingen nach konstanz
# bei einer chemischen reaktion entstehen neue stoffe mit neuen eigenschaften
# das programm kann schalten und walten wie es will
# im selben jahr kam es zu einem achttägigen generalstreik
# ich verstehe gar nicht weshalb darum so ein hype gemacht wird
# von herrn wiersma hörten wir dass dieses thema ein lieblingsthema der niederlande sei
# flashspeicher sollte man nicht defragmentieren
# die mangfall windet sich durch eine unberührte und ursprüngliche landschaft
# gebrannte grüne erde hat einen eher bräunlichen ton
# kommt das auch in den gelben sack
# somit ist auf der bever eine der frühen siedlungen in halver
# dies nur um zu verstehen was die verurteilungen durch die heutigen minister bedeuten
# man verdient nicht so viel wie in der freien wirtschaft arbeitet dafür aber entspannter
# wenn man mit offener heckklappe fährt sollte man stets auch vorne ein fenster öffnen
# der ausdruck ist analog zu alphabet gebildet
# stelle von den indiana pacers gezogen und sofort zu den portland trail blazers transferiert
# woran wir uns erinnern werden das sind die fernsehbilder brennender scheiterhaufen
# larissa hört auf ihrem mpdreiplayer meistens epische filmmusik
# udo ist ein morgenmuffel
# onkel dieter holte sein schweißgerät heraus und machte sich ans werk
# die höhe beträgt dabei üblicherweise mehr als fünf meter
# er blieb körperlich unverletzt und kam später frei
# liegt nürnberg in der nähe von dresden
# sein verhalten lässt den konsum von amphetaminen vermuten
# auch in den folgenden jahren platzierte sich der klub vornehmlich im bereich der aufstiegsplätze
# er hat wörterbücher und andere publikationen im bereich der indonesischen linguistik verfasst
# für mich als proeuropäer und föderalisten ist protektionismus antieuropäisch
# der berg ist ausserordentlich vielgestaltig
# mein partner hat ladehemmungen
# die spieler sehen alles aus der vogelperspektive
# indy weitergegeben der ebenfalls in kentucky für nachwuchs sorgte
# und schließlich gab es selbstlenkende geschosse
# hei
# der treiber hält sich strikt an die openglspezifikation
# nimm die augenklappe ab sonst siehst du nichts
# was liefern die lambdasonden an daten
# diese variante wurde jedoch nie in serie produziert
# barcelona ist die zweitgrößte stadt spaniens
# eins
# das koreanische alphabet wurde erst im fünfzehnten jahrhundert erfunden
# cds und andere optische datenträger sollte man nicht dem sonnenlicht aussetzen
# heute ist etterbeek eine der am dichtesten besiedelten gemeinden brüssels
# frauen einer
# jährlich wurde durch einen goldschmied eine neue rose im auftrag des papstes angefertigt
# reich mir den mal rüber
# nach einigen stunden setzt die totenstarre ein
# hier war das land waldfrei
# firefox
# ich habe eine zusatzfrage zu frau aherns frage
# nichts davon steht hier im grunde zur diskussion
# beim start oder bei der landung konnte man nach vorne fast nichts sehen
# du wirst es nicht glauben aber ich habe ihm erlaubt xbox zu spielen
# auf einem großen plakat ist der stammbaum von familie vogt dargestellt
# der weg führt einmal um den weiher herum
# er nahm am ersten weltkrieg teil und gehörte nach kriegsende einem freikorps an
# ob jemand der beste aller zeiten war kann heute niemand sagen
# das ist noch unklar und unklarheit im strafrecht verletzt das rechtsgefühl
# wikinger sind cool
# das ägyptische totenbuch ist eine wichtige dokumentation der ägyptischen mythologie
# ihr habt die wahl zwischen billig und komfortabel
# für solche zwecke hat nina einen diener
# alles entfernen
# aktuell tritt sie als schlagersängerin jasmin herren auf
# unsere teppiche haben alle dieselbe farbe
# in den ersten jahren bestand die brücke aus holz
# auf den ersten blick scheint das problem trivial zu sein
# zeige mir die kürzeste route nach hause
# die nützen einem freilich nichts wenn die batterie leer ist
# in der show trat unter anderen auch cilla black auf
# wunder der technik falls diese auch funktioniert
# ist es normal sich mit seinen arbeitskollegen besser zu verstehen als mit seiner frau
# der fahrplan war kreuzungsfrei
# für die ukraine ist es nicht einfach tschernobyl abzuschalten
# sehr vernünftig von dir
# ihr sitz ist in valencia der hauptstadt des bundeslandes carabobo
# in den meisten fällen musste der verein seine jugendspieler frühzeitig abgeben
# um ihr den aufenthalt auf der kinderstation etwas erträglicher zu machen brachte peter seiner tochter eine tafel schokolade mit
# beide schauspieler lebten während des projektes vorübergehend in einer wohngemeinschaft
# ulaanbaatar ist die hauptstadt von mongolei
# in china ist ein sack reis umgefallen
# ihr fell ist an der oberseite dunkelbraun und an der unterseite weißgrau gefärbt
# dabei gingen viele kundinnen leer aus
# gott sieht alles
# gierig kippte er sich noch mehr von dem zeug in den schlund
# du und deine bucklige verwandschaft
# trotz der unerfreulichen ereignisse möchte ich noch mal an das positive erinnern
# lebensjahr gearbeitet
# ohne wohnung ist das eine ohne heimat das andere
# diese wurden unter dem namen intelsat americas in die flotte eingereiht
# die anziehung des mondes erzeugt tiden
# auf ihnen befinden sich wortbildkombinationen
# die band schuf ein erstes demo mit einem drumcomputer anstelle eines schlagzeugers
# die gemeinsame tochter bringt die beiden wieder zusammen
# achtung abzocke
# das kann unmöglich dein ernst sein
# selbst für den erfahrensten chirurgen ist der tumor eine knifflige herausforderung
# so steht es wörtlich geschrieben
# deshalb muss man den eigennutz aber nicht komplett vernachlässigen
# wenn du dich beeilst bekommst du noch den zug um viertel nach fünf nach mainz
# das tiefe brummen ist charakteristisch für dieselmotoren
# auf diesen stil konzentrierte er sich in seiner ganzen ringerlaufbahn
# neun
# was sieht kamera eins gerade
# in einem brief schüttet sie ihr herz aus
# aus irgendeinem grund fährt der kaminkehrer heute mit einem vierzigtonner vor
# auf jeden fall müssen wir auch die politische lehre ziehen
# er studierte an der university of miami und an der stanford university
# sie hatte nur gute absichten
# er ist zudem dozent für komposition und musiktheorie an der hochschule der künste bern
# außerdem wusste herr korte seine beruflichen ziele mit seinen privaten zu verbinden
# franz ist ein spezialist für solche dinge
# das gerüst wäre mir zu wackelig
# als grund dafür wurden die schlechten einschaltquoten genannt
# vor uns fuhr ein streifenwagen der uns mittels kelle dazu aufforderte anzuhalten
# das steht doch alles im wiki
# austragung der nationalen titelkämpfe im badminton von jamaika
# die hauptstrecke hat ihren anfangspunkt in der nähe des hafens von bastia
# daher ist er beliebt bei jungen menschen und singles
# bei vier leuten bietet sich eine raute als aufstellung an
# ach daher weht der wind
# licht in der garage einschalten
# die zeit ist reif
# weil ja jede regel habe ich schon angewendet oder x ist nicht enthalten
# wir stehen in einer winwinsituation
# eine umlaufende linie ist dabei wichtig die die treppe komplett vom baukörper trennt
# was heißt das auf serbokroatisch
# daraufhin wurde er emir einer tausend und polizeichef von kairo
# kann ich dir ein geheimnis anvertrauen
# zu wartungszwecken hatte man den radkasten abmontiert
# wieso bin ich auf einmal so motiviert
# er ist dem barockstil zuzuordnen
# es wurden großformatige fotografien gezeigt
# die maßnahmen dürfen nicht und sollten nicht von fall zu fall erfolgen
# unmittelbar nördlich der eisenbahntrasse liegt der naturpark bautzen mit der schulsternwarte „johannes franz“
# das gesangstrio war auch an collins’ album ultra wave beteiligt
# du kannst die existenz des stigmas nicht völlig außer acht lassen
# cool ihr habt pfirsiche aus eigenem anbau
# sind sie bitte so nett
# direkt unterhalb des hanges verläuft das flüsschen grone
# der berechnung wird die dreipunkteregel zugrunde gelegt
# wie wir hier sehen können hat diese landkarte einen maßstab von eins zu einhunderttausend
# wer hat lust auf eine stadtrundfahrt
# mit zwei so kleinen rackern im schlepptau hat man manchmal ganz schön zu rackern
# die handlung spielt in einem hellen bunten surrealen ort dem fimbletal
# wir müssen sehr viel weiter gehen
# bleiben sie bitte nicht hier stehen
# derzeit zerbrechen in meinem freundeskreis überall beziehungen
# sie feuerten in den christlich dominierten stadtteilen in moslemische menschenansammlungen
# und wenn etwas passiert während wir speisen
# dort entsteht sein archäologisches zentrum
# der amtierende ratspräsident sollte allen beiträgen zuhören
# damit könnte man eine menge unfug anstellen
# wer in der nordsee baden geht sollte an ebbe und flut denken
# verächtlich blickte ich den jäger an
# in dieser position führte carl gezogene geschützrohre statt der bisherigen glatten rohre ein
# wenn meine großeltern sich miteinander unterhalten schnacken sie platt berichtet gerhard
# bis zu seinem tod blieb er präsident dieses vereins
# wie wunderschön du bist
# einer anderen überlieferung zufolge brachte man ihn später aus askalon nach kairo in sicherheit
# einer seiner ersten großen aufträge war die ausschmückung eines saales des palazzo farnese
# auch die restlichen bandmitglieder schweigen über seinen verbleib
# sie sprechen gilaki eine sprache die eng mit dem masandaranischen verwandt ist
# als gründe werden musikalische persönliche und finanzielle differenzen kolportiert
# frühzeitig begann die nutzung der braunkohle die in ammendorf abgebaut wurde
# zudem bin ich mir dessen bewusst dass die europäische wirtschaft eine dienstleistungswirtschaft ist
# verkauft der automat auch fahrkarten nach mülheim an der ruhr
# er kann mit fug und recht behaupten alles probiert zu haben
# kay und carol haben eine scharade vorbereitet in der mrs
# der weiße stock wurde dann offiziell als schutz und erkennungszeichen blinder menschen anerkannt
# das paar hinterließ zwei töchter
# dabei spielen die ägyptischen götter die weitere herrschaft über das land unter sich aus
# der friedrichsplatz liegt im osten der innenstadt
# schwieriger ist die vorhersage wenn noch keine strukturen ähnlicher aminosäuresequenzen bekannt sind
# aber woher kommt der wellenberg auf der mondabgewandten seite
# er nannte diesen vorgang auch synopse
# engineers sept
# eine dotierung mit gallium wäre beispielsweise möglich
# seit gerda gegangen ist fühlt uwe sich einsam
# michael hat die rolle dafür bekommen
# es wurde platz für unternehmen geschaffen
# das ist die folge einer verantwortungslosen politik nach dem ende der kolonialzeit
# derlei kontrollen sind dem urteil zufolge nicht zumutbar
# das ist uns bisher nicht gelungen
# residenzort war die gleichnamige stadt brieg
# er war als zimmermann bei der firma krupp in magdeburg beschäftigt
# er hat seinen sitz in hofheim am taunus im maintaunuskreis
# seit der polizeifunk digital ist kann man ihn nicht mehr mit dem radio abhören
# die siedlung wuchs stetig weiter schulen und straßen wurden gebaut
# ich lasse mir nicht von anderen vorschreiben ob ich einen minirock tragen darf
# in ihren händen hielt lotte den aktuellen katalog
# in diesem sommer haben wir auf der ostsee etwas bisher nie dagewesenes gesehen
# es hilft alles nichts
# sind die sätze so in ordnung
# aktuelle studien dazu fehlen
# das ist nicht aufrichtig gegenüber den beschwerdeführenden bürgern
# kneten sie den teig gut durch
# ich möchte die kommission bitten dies rechtzeitig zu tun
# reiss war verheiratet und hinterließ drei kinder
# das backsteingebäude bestand aus zwei stockwerken mit einer kuppel an der spitze
# hast du noch was zu trinken
# und so geht es im gänsemarsch bis zum ärmelkanal
# dieser anforderung folgend wurde die kanone der krupp entwicklung nr
# lima ist die hauptstadt von peru
# wie lange ist der letzte ölwechsel her
# die kommissarinnen nehmen ihn fest und befragen ihn
# ach hier sind wir
# ich kann mich nicht beklagen
# und ab geht die post
# novellen machen spaß weil man schnell durch ist
# es beherbergt weltweit die größte sammlung zeitgenössischer belgischer mode
# sie wird dir lauter dinge in dein ohr säuseln die dich schmeicheln sollen
# diese rolle verstärkte seine beliebtheit innerhalb der palästinensischen bevölkerung
# seither trug fast jede generation dazu bei dieses gotteshaus zu erweitern oder auszuschmücken
# sie arbeitet an einer erweiterung visueller methoden für sozialwissenschaftliche forschung
# ich war es nicht
# bei einigen tongefäßen gibt es ebenfalls verbindungen zum unteren donauraum
# die handlung spielt in einem vorort von chicago
# der bahnhof petersfield ist der nächstgelegene bahnhof östlich des dorfes
# wichtig ist dass im gefolge dieser empfehlung etwas geschieht dass ein rechtsrahmen geschaffen wird
# hmilch schmeckt einfach eklig
# hartmut du wirst alt
# und heraus kommt folgendes interferenzmuster
# seine romane wurden später veröffentlicht sowohl in buchform als auch serialisiert in magazinen
# sein markenzeichen ist der gezwirnte schnurrbart
# wir brauchen eine neue politische architektur um uns all dieser fragen annehmen zu können
# die frühesten werke seiner studienzeit waren vorwiegend radierungen
# gegen laugen verhält es sich stabil
# er wurde als mörder beschimpft und bedroht
# merkur ist der sonne so nah wie kein anderer planet
# willst du sie untergluckern oder was
# wieso das ist doch prima
# bei offenen spielen gilt grundsätzlich schwarz angesagt
# was er zum schluss gesagt hat hat sie tief berührt
# somit wurde nur die hälfte der rettungsboote genutzt
# zum zweiten müssen wir auch in der internationalen politik unsere rolle verantwortungsvoll wahrnehmen
# es bedeutet auch mehr arbeitslosigkeit und mehr sozialen rückschritt
# an der pastatheke wird nachschub benötigt
# der film entstand nach den gleichnamigen kinderbüchern von gerhard holtzbaumert
# am liebsten hätte sie den bernhardiner direkt aus dem tierheim mitgenommen
# am abend standen die sieger erneut vor hildesheim das sie zuvor lange belagert hatten
# das geld muss schnell ausgegeben werden egal wofür
# natürlich hätten wir gern ein höheres wachstum und natürlich ist unser handlungsspielraum begrenzt
# anders sieht die sache beim freien dienstleistungs und personenverkehr aus
# lebensjahr ski
# die anzahl der hafenbetreiber sollte nur aus zwingenden gründen eingeschränkt werden
# ich kann nicht erkennen was es ist
# bei der landung hat sina sich auf die zunge gebissen
# es gibt mehrere vereine vor ort
# ach das ist ja sympathisch
# nein ich bezahle das selbst
# ich bin mit ihrer korrektur nicht einverstanden
# er hat sich maßgeblich für den frieden eingesetzt
# die gymnasiale oberstufe ist nach dem kurssystem mit schwerpunkt organisiert
# im unterengadin machte ihn werner zimmermann mit der freiwirtschaftslehre von silvio gesell bekannt
# westliche staaten strebten seit der aufklärung eine trennung zwischen staat und religion an
# über einen zahnriemen oder eine kette ist sie mit der motorwelle verbunden
# durch vermehrten einsatz der schweißtechnik wurde die anwendung in diesem bereich zurückgedrängt
# eine geplante serienfertigung scheiterte
# inzwischen ist der gaspreis nicht mehr an den ölpreis gekoppelt
# nur carmen findet das unfair
# was kannst du eigentlich
# da versucht ernsthaft einer den blumenkübel mit dem auto wegzuschieben
# aber wir wollen die pferde ja auch nicht unnötig scheu machen
# sie war präsidentin der canadian astronomical society
# in meinen augen ist gustav vom scheitel bis zur sohle ein frommer christ urteilte pastor sigmund
# ich habe schon viel von ihnen gehört
# aktuell enthält das kreisrunde logo den markennamen in weißer kursiver schrift auf rotem grund
# die union braucht eine globale makroökonomische steuerung
# die außengestaltung erfolgte typisch in einem der vielen stilrichtungen des historismus
# wer vor allen herausforderungen wegrennt wird nie eine meistern
# der stellungskrieg an der westfront war eine sinnlose materialschlacht
# später wandte er sein interesse der klassischen musik zu
# vor dem kindergarten steht eine alte kastanie
# er zählt zu den gipfeln im teutoburger wald
# bei deutschen meisterschaften erreichte sie zweimal den dritten rang
# nach sorgfältiger analyse wurde bruno als schad beziehungsweise problembär eingestuft
# deine erklärung erweckt den anschein als hätte ein mensch die osmose erfunden
# sie warten regelmäßig mit überregionalen erfolgen bis auf landesebene auf
# wo geht es zur sparkasse
# und schließlich gab es selbstlenkende geschosse
# daher kommt unsere kritische haltung zu diesem bericht
# jetzt haben wir leider gar kein geld mehr für den pizzaboten
# er war mit drei goldmedaillen der erfolgreichste sportler bei diesen weltmeisterschaften
# schweres fehlverhalten wird mit einer schriftlichen missbilligung geahndet
# ich habe weiterhin einige einzelfragen zur ablehnung von anträgen auf information präzisiert
# ein kind aus der klasse ist versetzungsgefährdet
# ihre sprache tem gehört mit zur gurgruppe der nigerkongosprachen
# das fahrzeug hatte diverse technische mängel und auch die fragile funkfernsteuerung bereitete häufig probleme
# die naresstraße war in diesem jahr aber unbefahrbar
# doch dann flog die tür auf und unterbrach ihn
# nehmt euch ein paar flaschen pyramidenbräu mit
# ich wollte eigentlich nicht nach speyer fahren
# fünf
# ich werde niemals in die ferne schweifen
# manchmal ist es das klügste sich dumm zu stellen
# dürfen wir eine formelsammlung verwenden meldete sich meike zu wort
# denn auch letztere überschätzen ihre eigene kompetenz allzu oft
# bei allen unfällen wurden die vorgeschriebenen verfahren durch die besatzungen nicht eingehalten
# marvin versucht sich daran den erweiterten euklidischen algorithmus in haskell zu implementieren
# obiger versuchsaufbau stellt ein beispiel für simultaneous matchingtosample dar
# bis jetzt gab es kein gesetz zur regelung der arbeitszeiten selbstständiger unternehmer
# xena ist eine weitere herausforderin von arthurs autorität
# auch der moderne einkauf folgt hier dem klassischen ansatz von angebot und nachfrage
# aber dazu gab es in feira nichts
# sie sind in einigen teilen europas wahrscheinlich populärer als in deutschland selbst
# unter diesem gesichtspunkt hat er bestimmte richtungen der philosophie und der psychologie kritisiert
# name alter und adresse herauszufinden war für den meisterdetektiv ein leichtes
# lass mich damit in ruhe ich habe urlaub
# stets zu diensten mein herr
# jeder im schweinemarkt weiß woher diese krise kommt
# alle vegetativen teile sondern bei verletzung einen weißen milchsaft ab
# das wird die einhaltung der prinzipien von konzentration und flexibilität nicht erleichtern
# die mitglieder und ihr werk
# einige remoras sind in erster linie mit bestimmten wirtsarten verbunden
# die größe der beutetiere kann sehr unterschiedlich sein
# aufgrund ihrer einfachen gestaltung wird den gedenksteinen teils sogar die bezeichnung als denkmal abgesprochen
# wen habt ihr in erdkunde
# besitz und burg kamen an die markgrafen von hachbergsausenberg
# nachgeordnet sind die arbeitsgerichte erfurt gera nordhausen und suhl
# gesundheitsüberwachung und nachfolgende kontrollen sind gemäß nationaler praxis durchzuführen
# ...
# tabea setzte zum endspurt an
# alina ist immer so perfektionistisch
# das ist kein genuss sondern kampftrinken
# der doktor diagnostizierte eine blasenentzündung
# erzähl es der parkuhr aber lass mich in ruhe
# kann man von essen bis dortmund laufen
# wer nach rheinlandpfalz zieht ist selbst schuld wenn er den straßenkarneval aushalten muss
# das hilft auch beim einschlafen
# ich schwöre damit habe ich nichts zu tun
# das hauptquartier der firma befindet sich in karlsruhe
# ist der dritte teil auch so sehenswert wie die ersten zwei
# sehen ist ein passiver vorgang
# inge setzte wieder ihr pokerface auf
# wir werden alle sterben
# ich will ein kind von dir
# valentin hat das handtuch geworfen
# zum schluss wird alles mit geriebenem käse bestreut
# das gewebe ist von kunstfasern durchzogen
# wie wars in amsterdam
# meine erinnerung daran ist schon sehr verblasst
# man sollte nichts auf dem herd ablegen was nicht hitzebeständig ist
# suva ist die hauptstadt von fidschi
# das wasser spritzt so schön in alle richtungen
# dieses gebäude war über jahrzehnte die zentrale des illegalen imperiums
# die weihnachtsgeschichte beginnt mit einer volkszählung
# kann mich jemand hören sprach er in sein funkgerät
# auf dem weg haben wir einen konvoi der bundeswehr aus fünfzehn fahrzeugen überholt
# im kamin lodert ein feuer
# jemand muss den schornsteinfeger hereinlassen
# patricia warnte ihre mitspielerinnen
# bitte lauter stellen
# dadurch vervielfacht sich die zahl
# hoffen wir dass er nochmal ein auge zudrücken wird
# vielleicht wäre es für alle das beste
# programm öffnen
# reiß dich am riemen
# mit einem ruck setzte sich die kabine in bewegung
# dort führt eine schmale brücke über den bach
# ich möchte mich über den schlechten service in der werkstatt beschweren
# wohin mit all dem kleingeld
# kerstin besuchte ein onlinevergleichsportal um eine geeignete unterkunft zu finden
# schmeiß schon mal den grill an
# dem könig noch beschwipst vom wein fiel direkt ein ausweg ein
# browser öffnen
# plötzlich hielt mir jemand eine pistole an die schläfe
# zwei der satelliten sind leider nicht auf der vorgesehenen umlaufbahn
# was geht hier vor
# bitte sage nicht kalorien wenn du kilokalorien meinst das ist ein unterschied um den faktor tausend
# die beeren sind noch nicht reif
# herr ober wir möchten zahlen
# ich wollte eigentlich nicht nach saarbrücken fahren
# ist nicht so schlimm versucht helga zu trösten
# durch seine glaubhafte betonung haucht er den geschichten leben ein
# ich habe diesen ansatz noch nie gesehen
# einige dinge können auch in einem konsulat erledigt werden
# buenos aires ist die hauptstadt von argentinien
# irgendwie habe ich hier überhaupt keinen empfang
# christopher sieht sich in seiner ehre verletzt
# das eis ist so kalt dass es dampft
# hast du dein ticket nach görlitz schon gebucht
# was gibt es da zu lachen
# okay das ist nur ein flüchtigkeitsfehler
# ab einem bestimmten wert müssen eingeführte waren verzollt werden
# teil der ausstellung ist ein mittelalterliches katapult
# frau schmidt hat sich die nase gestoßen
# was heißt das auf finnisch
# liste anzeigen
# eine umleitung ist eingerichtet
# lecker es gibt weintrauben
# der zug nach frankfurt am main ist schon um dreiviertel drei abgefahren
# haben wir es eher mit isotroper oder mit anisotroper diffusion zu tun
# zudem gab es insgesamt weniger handel zwischen ost und west
# lou konnte sich gar nicht wieder einkriegen
# an welcher autobahnabfahrt muss ich die autobahn verlassen wenn ich nach badenbaden möchte
# die täterin wurde offenbar unterbrochen
# auch spanisch ist eine weltsprache
# in der schule haben wir mit delphi programmiert
# bestehen menschen aus mehr als aus fleisch und knochen
# wir haben da was auf dem radar
# ein problem mit dem proprietären treiber verhindert dass der computer aus dem standby aufwacht
# der ganze körper muss unter spannung stehen
# ich nehme sie mit auf meine reise ins flächenland
# in schritt zwei extrahieren wir die wichtigsten features
# es müssen auch alle in dieselbe richtung ziehen
# nach der einführung des alkoholverbots gingen reinigungskosten und vandalismusschäden signifikant zurück
# erst jetzt fiel mir auf dass dem mann ein fuß fehlte
# mit ihrer firma ist tatjana ordentlich am kohle scheffeln
# heutzutage lassen sich beide brücken kostenlos überqueren
# bei dem versuch sich die funktionsweise eines planetengetriebes vorzustellen wurde ilse schwindelig
# das katzenauge ist abgefallen
# funde von biologen belegen sogar dass es eine art kultur gibt die von generation zu generation weitergegeben wird
# aber bitte nur mit betäubung
# wir brauchen ein alleinstellungsmerkmal
# im allgäu fällt bereits erster schnee
# letzten dialog löschen
# hat stuttgart einen bahnhof
# hier sehen sie unsere kronjuwelen
# nach vierzigjähriger herrschaft des diktators gibt es nun einen wechsel
# reg dich nicht auf
# hier geht es um die wurst
# franziska kann derzeit nicht schreiben weil ihr handgelenk wehtut
# kann man heute in essen mit minustemperaturen rechnen
# alles hat ein ende nur die wurst hat zwei
# die insassen mussten per hubschrauber gerettet werden
# wir sind zwillinge
# touristen winkten den leuten am ufer zu
# unter dem motto rauchen gegen rassismus
# ich habe sie gar nicht in meiner datenbank sagte die sachbearbeiterin ratlos
# atome können moleküle bilden
# ich bringe euch bis nach hamburg
# margret versucht mit allen mitteln die drohende katastrophe abzuwenden
# das kind ist bereits in den brunnen gefallen
# viktoria und die anderen haben sich köstlich amüsiert
# nein aber flickzeug
# der geringe phwert verhindert effektiv dass sich schimmel bilden kann
# was ist gerade los auf twitter
# eduard musste eine vollbremsung hinlegen
# der landbasierte handel zwischen ost und west verlor an relevanz
# henrik hat bereits taucherbrille und schnorchel aufgesetzt
# junge junge das war knapp
# gibt es denn kein limit
# es ist unhöflich einen baum nach seiner geschichte zu fragen
# außerdem hatte er einen hellen pullover an auf dem der name irgendeiner amerikanischen stadt stand
# das ist zwar ein früher entwurf aber die grundidee lässt sich bereits erkennen
# wunschliste anzeigen
# licht im wohnzimmer aus
# der nordostseekanal wird stärker befahren als der panamakanal
# ab zwanzig uhr dürfen die öffentlichrechtlichen sender keine werbung mehr zeigen
# patricia schläft tief und fest
# das band muss wirklich straff gezogen werden
# machs gut
# fridolin hatte einen unfairen vorteil
# rasenfläche betreten verboten
# schau mal in der legende nach
# seit franziska kein semesterticket mehr hat kauft sie sich regelmäßig eine monatskarte
# die hauptstadt der bundesrepublik deutschland ist berlin
# im wohnzimmer meiner großeltern steht ein marmortisch
# sven hat eine eichel gefunden
# klaus hat sein referat noch nicht fertig
# ralf ist ein alter knacker sprach clemens wenig respektvoll
# irgendwo in der menschenmenge sind sie dann untergetaucht
# den größten beitrag zur masse eines atoms leistet der kern
# bridgetown ist die hauptstadt von barbados
# an dieser stelle ist vor zwei jahren eine gondel abgestürzt
# wenn man die teller direkt ins waschbecken stellt sind neunzig prozent des schmutzes bereits entfernt bevor man mit dem eigentlichen abwasch beginnt
# mach doch selber entgegnete vanessa trotzig
# herr böttcher ging mit seinem schäferhund spazieren
# dem werde ich ein angebot machen das er nicht ablehnen kann
# der zug nach wetzlar fährt heute am bahnsteig drei
# die münzprägung musste ebenfalls aufgegeben werden
# der alte kahn ächzte unter der last
# facebook öffnen
# umwege erhöhen die ortskenntnis
# bei diesem feuerlöscher handelt es sich um einen pulverlöscher
# die beiden hölzer wurden verleimt und zum trocknen einige stunden nicht angerührt
# muss ich wirklich wieder bis nach hagen fahren
# wem fällt ein reim auf asien ein
# es bleibt spannend abzuwarten ob wir eines tages von unserer eigenen schöpfung ausgerottet werden
# nach dem essen schüttelt nicola die tischdecke aus
# in seinen händen hielt herbert seine fristlose kündigung
# ein schelm wer böses dabei denkt
# ich muss nachladen
# lied nummer fünfhundertzweiunddreißig lässt sich besonders gut im kanon singen
# einige der zerstörten akten werden immer noch zusammengesetzt
# steht die internetverbindung
# emanuela ist sich unsicher wie sie ihr geld am sinnvollsten anlegen soll
# heidi wandte ihr gesicht ab
# stellt die post pakete auch am samstag zu
# verzeiht mir meine obszönitäten
# wir sind hier nicht bei wünschdirwas
# in welchem ressort würden sie bevorzugt arbeiten fragte der personalchef den juniorredakteur
# hast du mal eine feile oder ein stück schmirgelpapier
# woher hat der knabe nur seine aggressionen
# nebenbei bemerkt sind haferflocken auch reich an ballaststoffen
# verena ist erstaunt dass in dieser heterogenen gruppe alle so gut miteinander auskamen
# volker hat am vierzehnten märz geburtstag
# an pfingsten besuchen wir onkel heinz
# dieser fehler ist mir bei meinem letzten versuch unterlaufen
# marcel ist gut in informatik
# besserung ist nicht in sicht
# der kobold naschte vom grüngelben schleim
# der bus fährt nach heidelberg
# gibt es eine direkte bahnverbindung zwischen krefeld und nordhorn
# mir ist langweilig
# south tarawa ist die hauptstadt von kiribati
# wo kann man in bonn gut essen gehen
# von neunzehnhundertsiebundvierzig bis neunzehnhundertneunundfünfzig war karatschi die hauptstadt von pakistan
# es ist die fliehkraft die den motor bei zu hoher drehzahl zerstört
# ich mag kein gemüse
# ein paar jugendliche haben das dixiklo umgeworfen
# falls sie noch etwas training brauchen steht ihnen der übungsplatz zur verfügung
# dieser remix gefällt gerald nicht so gut
# willst du wirklich bis nach nürnberg fahren
# das konzept ist gut an der umsetzung müssen wir noch feilen
# die schnellrestaurantkette wird verdächtigt ihre mitarbeiter zu bespitzeln
# onkel dieter holte sein schweißgerät heraus und machte sich ans werk
# haben wir einen behälter für die walnussschale
# eine zivilperson wurde im kreuzfeuer getötet
# was heißt das auf bündnerromanisch
# champignons basilikum und olivenöl sind noch über
# julia fühlte sich unterfordert
# gibt es eine flugverbindung zwischen mainz und lübeck
# jetzt ist ärmel hochkrempeln angesagt
# onkel dagobert grüßt seinen neffen hieß es in dem harmlos anmutenden inserat
# dili ist die hauptstadt von osttimor
# jetzt hat jessica die zügel in der hand
# schwester jutta bitte zur notaufnahme schwester jutta bitte
# passen sie auf dass sich aus dem problemchen wie sie es nennen kein flächenbrand entwickelt
# was heißt das auf ungarisch
# thimphu ist die hauptstadt von bhutan
# aludeckel von plastikverpackungen sollte man abziehen bevor man sie in den gelben sack schmeißt
# das hat die kommission so entschieden
# nouakchott ist die hauptstadt von mauretanien
# der führer bläst zum angriff ins horn
# ich muss noch schnell zum metzger
# wie warm wird es morgen
# kinder sollten die grenzen ihrer eltern kennen
# probiers mal mit gemütlichkeit
# die datenbank wurde aktualisiert
# derzeit sind uns noch die hände gebunden
# der arktische ozean wird auch als nordpolarmeer oder nördliches eismeer bezeichnet
# keine widerrede das wird sofort erledigt
# und ab dieser stelle habe ich wieder eine erinnerungslücke
# er lügt dass sich die balken biegen
# und dies war von erfolg
# aufgabe der schule ist bildung nicht ausbildung erinnert der direktor die eltern
# der herrscher stimmte diesem zu denn er erkannte das dilemma im nu
# morgen kommt dora aus ihrem skiurlaub in sölden wieder
# rohkost ist für säuglinge nicht geeignet
# führerschein und fahrzeugpapiere bitte
# was bedeutet das für eubürger
# der japanische staatsgast deutete eine verbeugung an
# ist es in nürnberg nebelig
# vientiane ist die hauptstadt von laos
# sarajevo ist die hauptstadt von bosnien und herzegowina
# verzichten muss sie trotzdem nicht
# irina gibt immer ordentlich salz und pfeffer dazu
# der verteidigungsminister bezeichnete das manöver als klugen schachzug
# der jupiter ist der größte planet des sonnensystems
# dank der seilwinde konnte er wieder auf die straße gezogen werden
# die feststelltaste war nämlich aktiviert
# so drastisch würde ich es nicht ausdrücken
# waldemar zog den stöpsel
# der kapuzenpulli schien etwas zu klein zu sein
# voll auf die zwölf
# ein weiterer flugzeugträger ist bereits auf dem weg ins krisengebiet
# jeder wähler hat das recht sich die auszählung anzusehen
# die epoche wurde nach den riesigen stadtmauern benannt
# mit dem würde ich nicht gerne allein in einem raum sein
# beim derzeitigen pollenflug sollten allergiker lieber drinnen bleiben
# weil hannes zu spät aufgestanden war schaffte er es nicht mehr sich zu rasieren
# die letzte interaktion war erfolgreich
# darf ich dich auf ein eis einladen
# ein tütchen backpulver reicht für fünfhundert gramm mehl
# sie muss sich erst noch einleben
# quito ist die hauptstadt von ecuador
# was soll an dicken lippen schön sein
# wie lange werde ich heute zur arbeit brauchen
# nach der passkontrolle beginnt der transitbereich
# haben sie schon versucht das gerät aus und wieder einzuschalten
# wo sehen sie sich in fünf jahren
# totschweigen funktioniert immer
# die koreaner springen nun auch auf diesen zug auf
# warst du schon mal in herne
# damit übertrifft müller seinen bisherigen bestwert um fünf zehntel
# du bist spät dran
# dichter qualm entwich aus dem schornstein
# ist dir nicht gut
# kann man das kartenmaterial kostenlos herunterladen
# das kannst du laut sagen
# auf einem teller den niemand weggeräumt hatte lagen die stinkenden gräten vom vorabend
# die letzte interaktion war nicht erfolgreich
# zapfen sind für die farbwahrnehmung zuständig während die stäbchen das nachtsehen ermöglichen
# bei variabler bitrate geht immer die synchronisation zwischen audio und untertiteln verloren
# wenn man die inflation berücksichtigt sind die zinsen sogar negativ
# vielleicht ja beim nächsten softwareupdate
# mein sohn vermisst sein kuscheltier
# da muss man höllisch aufpassen
# darunter war auch ein liebesbrief aus dem jahr neunzehnhunderteinundzwanzig
# in einigen ländern kann man das visum direkt bei der einreise erwerben
# dir sind deine sachen verrutscht
# sport ist mord aber sportler scheinen viele leben zu haben
# möchten sie einchecken
# wann haben sie sich an der universität eingeschrieben
# in dem gerümpel sollen wir die skulptur finden
# tatjana ist total verstrahlt
# gibt es neue meldungen
# dies ist schlecht für die örtliche wirtschaft
# woher wussten sie von dem plan
# nur der gastgeber hat das recht weitere leute einzuladen
# seien sie froh
# das stauende liegt hinter einer kurve
# paris ist die hauptstadt von frankreich
# was heißt das auf niederländisch
# ich denke insgeheim hat stefanie sich schon so etwas gedacht
# wir regeln das später
# dein kleinwagen bietet im prinzip alles was man braucht ist aber etwas schwach auf der brust
# valerie wohnt in einem alten plattenbau aus ddrzeiten
# wann wurden die nomaden sesshaft
# ab wann muss man zum idiotentest
# ich habe meine brille vergessen
# die müritz ist der größte see der komplett innerhalb der bundesrepublik liegt
# thorsten kann schneller tippen als sprechen
# mozilla firefox beenden
# im zuge von sparmaßnahmen wurde ein drittel der belegschaft entlassen
# weitermachen
# es ist schon faszinierend dass regenwürmer und seesterne abgetrennte körperteile einfach regenerieren können
# mittels rasterfahndung sind sie ihm auf die schliche gekommen
# oskar schwelgte in erinnerungen
# für die einen eine heldentat für die anderen eine todsünde
# du bist wohl nicht mehr ganz dicht
# ja welches forum meine ich wohl
# niemand der es versucht hat hat den kern des planeten erreicht
# das ist unheimlich
# bitte leiser sprechen
# dein timing ist denkbar schlecht
# ankara ist die hauptstadt der türkei
# ich möchte nach trier
# flensburg ist kein vergleich zu stuttgart
# wer kann mir einen berühmten maler der postmoderne nennen
# und damit sind wir auch schon am ende der sendung leitete der moderator zum nächsten thema über
# dies ist das einzige kaufhaus der stadt in dem es noch einen paternosteraufzug gibt
# michaela kann endlich offen über das erlebte sprechen
# nehmen wir schwein rind oder gemischtes hackfleisch
# wenn man gegenstände auf die lüftungsschlitze von elektrischen geräten stellt kann es passieren dass diese überhitzen
# sie kramte in ihrer tasche
# libreville ist die hauptstadt von gabun
# das ramponierte image haben sie sich selbst zuzuschreiben
# er macht einen unterforderten eindruck
# mit der kippe sind sie für ihr kind gefährlicher als ich

# %%
import json


if __name__ == "__main__":
    results = json.load(open('/content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/results.json'))
    for test_file in results:
        ref_lens = [len(v["reference"].split(" ")) for v in results[test_file].values()]
        edits = [int(v["wer"] * ref_lens[i]) for i, v in enumerate(results[test_file].values())]
        print(test_file, round(sum(edits) / sum(ref_lens) * 100, 2))
# Out:
# test_at.txt 2.84
# test_gb.txt 5.08
# test_it.txt 2.25
# test_de_al.txt 2.06
# test_fr.txt 5.27
# test_de_ni.txt 5.68
# test_ch.txt 4.24
# test_de.txt 3.2
# test_us.txt 5.6
# test_ca.txt 5.0
# test_ru.txt 4.5

# %% [markdown]
# ####**<font color="1497d4">Bar chart: Word Error Rate - All Accent -Gender</font>** **x='accent', y = 'wer_accent_mean' according to gender Accent ='all Accent'**

# %%
#########################################################################################################################################################
####################Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate, and gender, Accent ='all Accent'##########################
#########################################################################################################################################################
print("################################## Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate, and gender, Accent ='all Accent' ###########################################")


############################################################################################################################################################
dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb','it','de_al','fr','de_ni','ch','de','us','ca','ru'],
                                          'accent_long':['Österreichisches Deutsch','Britisches Deutsch','Italienisch Deutsch','Alemannische Färbung,Schweizer Standart Deutsch',
'Französisch Deutsch','Niederländisch Deutsch','Schweizerdeutsch','Deutschland Deutsch','Amerikanisches Deutsch','Kanadisches Deutsch','Russisch Deutsch'],
                                        'test_accent_txt':['test_at.txt','test_gb.txt','test_it.txt','test_de_al.txt','test_fr.txt','test_de_ni.txt','test_ch.txt',
               'test_de.txt','test_us.txt','test_ca.txt','test_ru.txt']})
############################################################################################################################################################
 
##### def plotBarChartsDurrationGenderAllAccent():

 
#accent_long_var='Alemannische Färbung,Schweizer Standart Deutsch'

##############################################################################################################
# dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb'],
#                                           'accent_long':['Österreichisches Deutsch','Britisches Deutsch'],
#                                         'test_accent_txt':['test_at.txt','test_gb.txt']})

##############################################################################################################

list_accent_all_wer_mean_result=[]
dataset_accent_all_wer_mean_result=pd.DataFrame(list_accent_all_wer_mean_result,columns=['accent_short','accent_long','wer_accent_mean'])
##############################################################################################################

############################# 1- reading the dataset ##########################################################

for i in range(len(dataset_results_json_accent)):
  dataset_results_json = pd.read_json('results.json')
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)

  accent_short_var=dataset_results_json_accent['accent_short'][i]
  accent_long_var=dataset_results_json_accent['accent_long'][i]

  
  ###################################################################################################
  ###################Convert Json Index to column contents in dataframe #############################
  ###################################################################################################

  dataset_results_json['audio_filepath'] = dataset_results_json.index

  dataset_results_json['audio_filepath_index'] = dataset_results_json['audio_filepath'].str[-12:-4]
  
  ###>>> dataset_results_json_audio_filepath is the dataset_results_json DataFrame with the audio_filepath as index
  dataset_results_json_audio_filepath=dataset_results_json.reindex(dataset_results_json['audio_filepath_index'])

  

  # filling up the ['audio_filepath_numeric'] Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath['audio_filepath_numeric']=np.where(dataset_results_json['audio_filepath_index']!=np.NaN,dataset_results_json['audio_filepath_index'],'0000')


  # filling up the Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]]=np.where(dataset_results_json[dataset_results_json_accent.test_accent_txt[i]]!=np.NaN,
                                                                                               dataset_results_json[dataset_results_json_accent.test_accent_txt[i]],'000')
  
  # dataset_results_json_audio_filepath['accent_long']=np.where(dataset_results_json['accent_long']!=np.NaN,dataset_results_json['accent_long'],'000')
  # dataset_results_json_audio_filepath['test_accent_txt']=np.where(dataset_results_json['test_accent_txt']!=np.NaN,dataset_results_json['test_accent_txt'],'000')
 

 
  #################################Extract and calculate the wer_accent_numeric########################################
  # drop the NaN values of the accent "test_accent_txt"  by each one 
  dataset_results_json_audio_filepath.drop(dataset_results_json_audio_filepath[ (dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].isna())].index, inplace=True)

  
  # extract the numeric values of the WER durations from the accent Column and store it in a new column called wer_accent_numeric
 
  dataset_results_json_audio_filepath['wer_accent_numeric'] = dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
 

  # print('  dataset_results_json_audio_filepath','*'*60)
  # print(dataset_results_json_audio_filepath)

  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
  dataset_results_json_audio_filepath['audio_filepath_numeric']=dataset_results_json_audio_filepath['audio_filepath_numeric'].astype('int')
 

  
  ############################# 3- Drop all NaN gender and NaN Accent values, and show only the female gender and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[(dataset_validated_tsv['gender'] != 'female') | (dataset_validated_tsv['gender'].isna())| 
  (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  # print('*'*60,'dataset_validated_tsv')
  # print(dataset_validated_tsv)
  
 
  ############################# 4- Merge using audio_filepath_numeric column ##################################
  ####################5-calculate the Mean of WER when the gender is female###########################
  dataset_results_json_audio_filepath_validated_tsv_female=pd.merge(dataset_results_json_audio_filepath,dataset_validated_tsv)
  dataset_results_json_audio_filepath_validated_tsv_female['gender']=dataset_results_json_audio_filepath_validated_tsv_female['gender'].astype("string")
  
  dataset_results_json_audio_filepath_validated_tsv_female['accent_wer_mean_gender']=np.mean(dataset_results_json_audio_filepath_validated_tsv_female['wer_accent_numeric'])
  # print('*'*60,'dataset_results_json_audio_filepath_validated_tsv_female')
  # print(dataset_results_json_audio_filepath_validated_tsv_female)

  ###################################    Male Part   ##########################################################
  ############################# 6- reading the dataset ##########################################################
  ############################# 7- extract the audio_filepath number and change them to integer################## 
  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')




  
  ############################# 8- Drop all NaN gender and NaN Accent values, and show only the male gender and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[(dataset_validated_tsv['gender'] != 'male') | (dataset_validated_tsv['gender'].isna())| (dataset_validated_tsv['accents'].isna())
  | (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)

  ############################# 9- Merge using audio_filepath_numeric column ##################################
  dataset_results_json_audio_filepath_validated_tsv_male=pd.merge(dataset_results_json_audio_filepath,dataset_validated_tsv)
  dataset_results_json_audio_filepath_validated_tsv_male['gender']=dataset_results_json_audio_filepath_validated_tsv_male['gender'].astype("string")

  # print('*'*60,'dataset_results_json_audio_filepath_validated_tsv_male')
  # print(dataset_results_json_audio_filepath_validated_tsv_male)



  #################### 10- calculate the Mean of duration when the gender is male###########################
  dataset_results_json_audio_filepath_validated_tsv_male['accent_wer_mean_gender']=np.mean(dataset_results_json_audio_filepath_validated_tsv_male['wer_accent_numeric'])
  #dataset_results_json_audio_filepath_validated_tsv_male

  ###### add/append the upper dataset dataset_results_json_audio_filepath_validated_tsv_female to the lower dataset dataset_results_json_audio_filepath_validated_tsv_male###########################
  ###### and call the result dataset_results_json_audio_filepath_validated_tsv_family

#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_results_json_audio_filepath_validated_tsv_female.empty and not dataset_results_json_audio_filepath_validated_tsv_male.empty:
    dataset_results_json_audio_filepath_validated_tsv_family=dataset_results_json_audio_filepath_validated_tsv_female.append(dataset_results_json_audio_filepath_validated_tsv_male)
  elif dataset_results_json_audio_filepath_validated_tsv_female.empty and not dataset_results_json_audio_filepath_validated_tsv_male.empty:
    dataset_results_json_audio_filepath_validated_tsv_family=dataset_results_json_audio_filepath_validated_tsv_male
  elif dataset_results_json_audio_filepath_validated_tsv_male.empty and not dataset_results_json_audio_filepath_validated_tsv_female.empty:
    dataset_results_json_audio_filepath_validated_tsv_family=dataset_results_json_audio_filepath_validated_tsv_female
  else:
    data_3={'gender':['female','male'],'accent_wer_mean_gender':[0,0]}
    dataset_results_json_audio_filepath_validated_tsv_family=pd.DataFrame(data_3)

    ################### 11- plot the dataset_results_json_audio_filepath_validated_tsv_family in Bar Chart #######################
  # position of the figure and figure's size 
  figure_duriation_distribution_accent=plt.figure(12,figsize=(23,23))  
  #plt.subplots(figure's number per column,figure's number per row)

  # Sup_plot_position=f'dataset_test_{i}'

  # Sup_plot_position=Sup_plot_position.astype(int)
  ax_duriation_distribution_accent_at=figure_duriation_distribution_accent.add_subplot(3,4,i+1)
  font1 = {'family':'serif','color':'blue','size':20}
  font2 = {'family':'serif','color':'darkred','size':15}
  if accent_long_var=='Alemannische Färbung,Schweizer Standart Deutsch':
    font1 = {'family':'serif','color':'blue','size':13}
    accent_long_var='Alemannische Färbung,\n Schweizer Standart Deutsch'
  
  plt.title(f'{accent_long_var} - WER',fontdict  = font1)
  #ax.legend()
  #min([], default="EMPTY")
  ax = sns.barplot(x = 'gender', y = 'accent_wer_mean_gender', data = dataset_results_json_audio_filepath_validated_tsv_family)

  plt.xticks(rotation=70)
  plt.tight_layout()
plt.savefig('plotBarDiagrams_Accent_WER_gender.png')
# Out:
# ################################## Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate, and gender, Accent ='all Accent' ###########################################

# %% [markdown]
# ####**<font color="1497d4">Bar chart: Word Error Rate - All Accent - Age</font>** **x='accent', y = 'wer_Duration_mean' according to age where Accent ='all Accent'**

# %%
#########################################################################################################################################################
####################Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate, and age groups, Accent ='all Accent'##########################
#########################################################################################################################################################
print("################################## Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate, and age groups, Accent ='all Accent' ###########################################")





list_accent_all_wer_mean_result=[]
dataset_accent_all_wer_mean_result=pd.DataFrame(list_accent_all_wer_mean_result,columns=['accent_short','accent_long','wer_accent_mean'])

############################################################################################################################################################
list_dataset_test_=['at','gb','it','de_al','fr','de_ni','ch','de','us','ca','ru']
dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb','it','de_al','fr','de_ni','ch','de','us','ca','ru'],
                                          'accent_long':['Österreichisches Deutsch','Britisches Deutsch','Italienisch Deutsch','Alemannische Färbung,Schweizer Standart Deutsch',
'Französisch Deutsch','Niederländisch Deutsch','Schweizerdeutsch','Deutschland Deutsch','Amerikanisches Deutsch','Kanadisches Deutsch','Russisch Deutsch'],
                                        'test_accent_txt':['test_at.txt','test_gb.txt','test_it.txt','test_de_al.txt','test_fr.txt','test_de_ni.txt','test_ch.txt',
               'test_de.txt','test_us.txt','test_ca.txt','test_ru.txt'],
               'twenties':list_twenties,'thirties':list_thirties,'fourties':list_fourties,'fifties':list_fifties})
############################################################################################################################################################


############################################################################################################################################################



##### def plotBarChartsDurrationGenderAllAccent():

 
#accent_long_var='Alemannische Färbung,Schweizer Standart Deutsch'

##############################################################################################################
# list_dataset_test_=['at','gb']

# dataset_results_json_accent=pd.DataFrame({'accent_short':['at','gb'],
#                                           'accent_long':['Österreichisches Deutsch','Britisches Deutsch'],
#                                         'test_accent_txt':['test_at.txt','test_gb.txt'],
#                'twenties':list_twenties,'thirties':list_thirties,'fourties':list_fourties,'fifties':list_fifties})

##############################################################################################################
# four lists of iterations of twenties and thirties elements
list_twenties=list(map(lambda x:'twenties',list_dataset_test_))
list_thirties=list(map(lambda x:'thirties',list_dataset_test_))
list_fourties=list(map(lambda x:'fourties',list_dataset_test_))
list_fifties=list(map(lambda x:'fifties',list_dataset_test_))


##############################################################################################################

# def plotBarChartsDurrationageAllAccent():








############################# 1- reading the dataset ##########################################################

############################# 1- reading the dataset ##########################################################



for i in range(0,len(dataset_results_json_accent)):
  
  accent_short_var=dataset_results_json_accent['accent_short'][i]
  accent_long_var=dataset_results_json_accent['accent_long'][i]
  age_var_twenties=dataset_results_json_accent['twenties'][i]
  age_var_thirties=dataset_results_json_accent['thirties'][i]
  age_var_fourties=dataset_results_json_accent['fourties'][i]
  age_var_fifties=dataset_results_json_accent['fifties'][i]
  
  ###################################################################################################
  ###################Convert Json Index to column contents in dataframe #############################
  ###################################################################################################

#########################################################################################################################################################################
########################################################### ages 20 - 30 ################################################################################################
#########################################################################################################################################################################
  
  dataset_results_json = pd.read_json('results.json')
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)


  dataset_results_json['audio_filepath'] = dataset_results_json.index

  dataset_results_json['audio_filepath_index'] = dataset_results_json['audio_filepath'].str[-12:-4]
  
  ###>>> dataset_results_json_audio_filepath is the dataset_results_json DataFrame with the audio_filepath as index
  dataset_results_json_audio_filepath=dataset_results_json.reindex(dataset_results_json['audio_filepath_index'])

  
  ##############################################################################################################################
  ####### filling up the ['audio_filepath_numeric'] Values of dataset_results_json_audio_filepath form dataset_results_json#####
  dataset_results_json_audio_filepath['audio_filepath_numeric']=np.where(dataset_results_json['audio_filepath_index']!=np.NaN,dataset_results_json['audio_filepath_index'],'0000')


  # filling up the Values of dataset_results_json_audio_filepath form dataset_results_json
  dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]]=np.where(dataset_results_json[dataset_results_json_accent.test_accent_txt[i]]!=np.NaN,
                                                                                               dataset_results_json[dataset_results_json_accent.test_accent_txt[i]],'000')
  
 

  #################################################################################################################
  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
  dataset_results_json_audio_filepath['audio_filepath_numeric']=dataset_results_json_audio_filepath['audio_filepath_numeric'].astype('int')




   
  #################################Extract and calculate the wer_accent_numeric########################################
  # drop the NaN values of the accent "test_accent_txt"  by each one 
  dataset_results_json_audio_filepath.drop(dataset_results_json_audio_filepath[ (dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].isna())].index, inplace=True)

  
  # extract the numeric values of the WER durations from the accent Column and store it in a new column called wer_accent_numeric
  dataset_results_json_audio_filepath['wer_accent_numeric'] = dataset_results_json_audio_filepath[dataset_results_json_accent.test_accent_txt[i]].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
 

  # print('  dataset_results_json_audio_filepath','*'*60)
  # print(dataset_results_json_audio_filepath)

  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
 


 
  ############################ 3-A Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_twenties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_twenties)].index, inplace=True)


  ############################ 3-B Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_twenties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  

  ############################# 4- Merge using audio_filepath_numeric column ##################################
  ####################5-calculate the Mean of duration when the age is twenties###########################
  dataset_results_json_audio_filepath_validated_tsv_twenties=pd.merge(dataset_results_json_audio_filepath,dataset_validated_tsv)
  dataset_results_json_audio_filepath_validated_tsv_twenties['age']=dataset_results_json_audio_filepath_validated_tsv_twenties['age'].astype("string")
  dataset_results_json_audio_filepath_validated_tsv_twenties['accent_wer_mean_age']=np.mean(dataset_results_json_audio_filepath_validated_tsv_twenties['wer_accent_numeric'])


  # ############################ 6- reading the dataset to make the calculations of the age thirties #################
  # ############################ 7- extract the audio_filepath number and change them to integer  #################### 
  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
   
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
         
# print('##'*20,accent_long_var,'##'*60)
# print(dataset_validated_tsv)

  # ############################# 8-A Drop all NaN age and NaN Accent values, and show only the thirties -->>age_var_thirties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_thirties)].index, inplace=True)

############################ 8-B Drop all NaN age and NaN Accent values, and show only the twenties-->>age_var_thirties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)

# print('##'*20,accent_long_var,'##'*60)
# dataset_validated_tsv

 
  ############################# 9- Merge using audio_filepath_numeric column ##################################
  dataset_results_json_audio_filepath_validated_tsv_thirties=pd.merge(dataset_results_json_audio_filepath,dataset_validated_tsv)
  dataset_results_json_audio_filepath_validated_tsv_thirties['age']=dataset_results_json_audio_filepath_validated_tsv_thirties['age'].astype("string")


  #################### 10- calculate the Mean of duration when the age is thirties###########################
  dataset_results_json_audio_filepath_validated_tsv_thirties['accent_wer_mean_age']=np.mean(dataset_results_json_audio_filepath_validated_tsv_thirties['wer_accent_numeric'])
  #dataset_results_json_audio_filepath_validated_tsv_thirties
  ###### add/append the upper dataset dataset_results_json_audio_filepath_validated_tsv_twenties to the lower dataset dataset_results_json_audio_filepath_validated_tsv_thirties###########################
  ###### and call the result dataset_results_json_audio_filepath_validated_tsv_20_30
  ####>>>>>>>dataset_results_json_audio_filepath_validated_tsv_20_30=dataset_results_json_audio_filepath_validated_tsv_twenties.append(dataset_results_json_audio_filepath_validated_tsv_thirties)







####11212121212121





  
  

#   ###### add/append the upper dataset dataset_results_json_audio_filepath_validated_tsv_female to the lower dataset dataset_results_json_audio_filepath_validated_tsv_male###########################
#   ###### and call the result dataset_results_json_audio_filepath_validated_tsv_family

# #########################################################################################################################################################################
# ########################################################### test if the dataframes are empty!##############################################################################
# #########################################################################################################################################################################

#   if not dataset_results_json_audio_filepath_validated_tsv_female.empty and not dataset_results_json_audio_filepath_validated_tsv_male.empty:
#     dataset_results_json_audio_filepath_validated_tsv_family=dataset_results_json_audio_filepath_validated_tsv_female.append(dataset_results_json_audio_filepath_validated_tsv_male)
#   elif dataset_results_json_audio_filepath_validated_tsv_female.empty and not dataset_results_json_audio_filepath_validated_tsv_male.empty:
#     dataset_results_json_audio_filepath_validated_tsv_family=dataset_results_json_audio_filepath_validated_tsv_male
#   elif dataset_results_json_audio_filepath_validated_tsv_male.empty and not dataset_results_json_audio_filepath_validated_tsv_female.empty:
#     dataset_results_json_audio_filepath_validated_tsv_family=dataset_results_json_audio_filepath_validated_tsv_female
#   else:
#     data_3={'gender':['female','male'],'accent_wer_mean_gender':[0,0]}
#     dataset_results_json_audio_filepath_validated_tsv_family=pd.DataFrame(data_3)



# ####191991911919919911912020225250252022250502520252550520202506575475475475754756754754675467457546754675475467567547547546754675757576
# ####191991911919919911912020225250252022250502520252550520202506575475475475754756754754675467457546754675475467567547547546754675757576
# ####191991911919919911912020225250252022250502520252550520202506575475475475754756754754675467457546754675475467567547547546754675757576


  

 





#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_results_json_audio_filepath_validated_tsv_twenties.empty and not dataset_results_json_audio_filepath_validated_tsv_thirties.empty:
    dataset_results_json_audio_filepath_validated_tsv_20_30=dataset_results_json_audio_filepath_validated_tsv_twenties.append(dataset_results_json_audio_filepath_validated_tsv_thirties)
  elif dataset_results_json_audio_filepath_validated_tsv_twenties.empty and not dataset_results_json_audio_filepath_validated_tsv_thirties.empty:
    dataset_results_json_audio_filepath_validated_tsv_20_30=dataset_results_json_audio_filepath_validated_tsv_thirties
  elif dataset_results_json_audio_filepath_validated_tsv_thirties.empty and not dataset_results_json_audio_filepath_validated_tsv_twenties.empty:
    dataset_results_json_audio_filepath_validated_tsv_20_30=dataset_results_json_audio_filepath_validated_tsv_twenties
  else:
    data_3={'age':['twenties','thirties'],'accent_wer_mean_age':[0,0]}
    dataset_results_json_audio_filepath_validated_tsv_20_30=pd.DataFrame(data_3)


#########################################################################################################################################################################
########################################################### ages 40 - 50 ################################################################################################
#########################################################################################################################################################################



  ####>>>>>dataset_results_json = pd.read_json('results.json')

  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  




  # ############################# 2- extract the audio_filepath number and change them to integer################## 

  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')
  dataset_results_json_audio_filepath['audio_filepath_numeric']=dataset_results_json_audio_filepath['audio_filepath_numeric'].astype('int')


  ############################ 3-A Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fourties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_fourties)].index, inplace=True)


  ############################ 3-B Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fourties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  

  

  ############################# 3- Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fourties age and accent_long_var rows #############################
  # dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_fourties) |
  # (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)
  #dataset_validated_tsv



  ############################# 4- Merge using audio_filepath_numeric column ##################################
  ####################5-calculate the Mean of duration when the age is fourties###########################
  dataset_results_json_audio_filepath_validated_tsv_fourties=pd.merge(dataset_results_json_audio_filepath,dataset_validated_tsv)
  dataset_results_json_audio_filepath_validated_tsv_fourties['age']=dataset_results_json_audio_filepath_validated_tsv_fourties['age'].astype("string")
  dataset_results_json_audio_filepath_validated_tsv_fourties['accent_wer_mean_age']=np.mean(dataset_results_json_audio_filepath_validated_tsv_fourties['wer_accent_numeric'])


  # ############################ 6- reading the dataset to make the calculations of the age fifties #################
  # ############################ 7- extract the audio_filepath number and change them to integer  #################### 
  # get the audio file number and display it at dataset_validated_tsv['audio_filepath_numeric']
  dataset_validated_tsv = pd.read_csv('validated.tsv', sep='\t',low_memory=False)
  dataset_validated_tsv['audio_filepath_numeric'] = dataset_validated_tsv['path'].str[-12:-4]
  dataset_validated_tsv['audio_filepath_numeric']=dataset_validated_tsv['audio_filepath_numeric'].astype('int')

# print('##'*20,accent_long_var,'##'*60)
# print(dataset_validated_tsv)

  # ############################# 8-A Drop all NaN age and NaN Accent values, and show only the fifties -->>age_var_fifties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['age'].isna())| (dataset_validated_tsv['age'] != age_var_fifties)].index, inplace=True)

############################ 8-B Drop all NaN age and NaN Accent values, and show only the fourties-->>age_var_fifties age and accent_long_var rows #############################
  dataset_validated_tsv.drop(dataset_validated_tsv[ (dataset_validated_tsv['accents'].isna())| (dataset_validated_tsv['accents']!=accent_long_var)].index, inplace=True)

# print('##'*20,accent_long_var,'##'*60)
# dataset_validated_tsv

 
  ############################# 9- Merge using audio_filepath_numeric column ##################################
  dataset_results_json_audio_filepath_validated_tsv_fifties=pd.merge(dataset_results_json_audio_filepath,dataset_validated_tsv)
  dataset_results_json_audio_filepath_validated_tsv_fifties['age']=dataset_results_json_audio_filepath_validated_tsv_fifties['age'].astype("string")


  #################### 10- calculate the Mean of duration when the age is fifties###########################
  dataset_results_json_audio_filepath_validated_tsv_fifties['accent_wer_mean_age']=np.mean(dataset_results_json_audio_filepath_validated_tsv_fifties['wer_accent_numeric'])
  #dataset_results_json_audio_filepath_validated_tsv_fifties
  ###### add/append the upper dataset dataset_results_json_audio_filepath_validated_tsv_fourties to the lower dataset dataset_results_json_audio_filepath_validated_tsv_fifties###########################
  ###### and call the result dataset_results_json_audio_filepath_validated_tsv_40_50
  ####>>>>>>>dataset_results_json_audio_filepath_validated_tsv_40_50=dataset_results_json_audio_filepath_validated_tsv_fourties.append(dataset_results_json_audio_filepath_validated_tsv_fifties)

#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_results_json_audio_filepath_validated_tsv_fourties.empty and not dataset_results_json_audio_filepath_validated_tsv_fifties.empty:
    dataset_results_json_audio_filepath_validated_tsv_40_50=dataset_results_json_audio_filepath_validated_tsv_fourties.append(dataset_results_json_audio_filepath_validated_tsv_fifties)
  elif dataset_results_json_audio_filepath_validated_tsv_fourties.empty and not dataset_results_json_audio_filepath_validated_tsv_fifties.empty:
    dataset_results_json_audio_filepath_validated_tsv_40_50=dataset_results_json_audio_filepath_validated_tsv_fifties
  elif dataset_results_json_audio_filepath_validated_tsv_fifties.empty and not dataset_results_json_audio_filepath_validated_tsv_fourties.empty:
    dataset_results_json_audio_filepath_validated_tsv_40_50=dataset_results_json_audio_filepath_validated_tsv_fourties
  else:
    data_3={'age':['fourties','fifties'],'accent_wer_mean_age':[0,0]}
    dataset_results_json_audio_filepath_validated_tsv_40_50=pd.DataFrame(data_3)

#########################################################################################################################################################################
########################################################### merge all ages: 20-30 with 40 - 50 ########################################################################## 
#########################################################################################################################################################################
  ###>>>>>>>>dataset_results_json_audio_filepath_validated_tsv_all_ages=dataset_results_json_audio_filepath_validated_tsv_20_30.append(dataset_results_json_audio_filepath_validated_tsv_40_50)


#########################################################################################################################################################################
########################################################### test if the dataframes are empty!##############################################################################
#########################################################################################################################################################################

  if not dataset_results_json_audio_filepath_validated_tsv_20_30.empty and not dataset_results_json_audio_filepath_validated_tsv_40_50.empty:
    dataset_results_json_audio_filepath_validated_tsv_all_ages=dataset_results_json_audio_filepath_validated_tsv_20_30.append(dataset_results_json_audio_filepath_validated_tsv_40_50)
  elif dataset_results_json_audio_filepath_validated_tsv_20_30.empty and not dataset_results_json_audio_filepath_validated_tsv_40_50.empty:
    dataset_results_json_audio_filepath_validated_tsv_all_ages=dataset_results_json_audio_filepath_validated_tsv_40_50
  elif dataset_results_json_audio_filepath_validated_tsv_40_50.empty and not dataset_results_json_audio_filepath_validated_tsv_20_30.empty:
    dataset_results_json_audio_filepath_validated_tsv_all_ages=dataset_results_json_audio_filepath_validated_tsv_20_30
  else:
    data_3={'age':['fourties','fifties'],'accent_wer_mean_age':[0,0]}
    dataset_results_json_audio_filepath_validated_tsv_all_ages=pd.DataFrame(data_3)


    ################### 11- plot the dataset_results_json_audio_filepath_validated_tsv_family in Bar Chart #######################

  #ax.legend()
  #min([], default="EMPTY")
  
  figure_duriation_distribution_accent=plt.figure(12,figsize=(25,25))  
  #plt.subplots(figure's number per column,figure's number per row)

  # Sup_plot_position=f'dataset_test_{i}'

  # Sup_plot_position=Sup_plot_position.astype(int)
  ax_duriation_distribution_accent_at=figure_duriation_distribution_accent.add_subplot(3,4,i+1)
  font1 = {'family':'serif','color':'blue','size':20}
  font2 = {'family':'serif','color':'darkred','size':15}
  if accent_long_var=='Alemannische Färbung,Schweizer Standart Deutsch':
    font1 = {'family':'serif','color':'blue','size':13}
    accent_long_var='Alemannische Färbung,\n Schweizer Standart Deutsch'

  plt.title(f'{accent_long_var} - WER',fontdict  = font1)
  #ax.legend()
  plt.xticks(rotation=70)
  plt.tight_layout()
  ax = sns.barplot(x = 'age', y = 'accent_wer_mean_age', data = dataset_results_json_audio_filepath_validated_tsv_all_ages)
plt.savefig('plotBarDiagramsAccent_WER_age.png')
# Out:
# ################################## Bar chart: x='accent', y = 'wer_accent_mean' according to Word Error Rate, and age groups, Accent ='all Accent' ###########################################

# %% [markdown]
# #Bar Charts Operations

# %%
import json


if __name__ == "__main__":
    results = json.load(open('/content/drive/MyDrive/QU-DFKI-Thesis-ASR/Experimentation/data/results.json'))
    for test_file in results:
        ref_lens = [len(v["reference"].split(" ")) for v in results[test_file].values()]
        edits = [int(v["wer"] * ref_lens[i]) for i, v in enumerate(results[test_file].values())]
        print(test_file, round(sum(edits) / sum(ref_lens) * 100, 2))
# Out:
# test_at.txt 2.84
# test_gb.txt 5.08
# test_it.txt 2.25
# test_de_al.txt 2.06
# test_fr.txt 5.27
# test_de_ni.txt 5.68
# test_ch.txt 4.24
# test_de.txt 3.2
# test_us.txt 5.6
# test_ca.txt 5.0
# test_ru.txt 4.5

# %% [markdown]
# # write to python file

# %% [markdown]
# ## <font color="1497d4">  **Running a Basic Emformer Training**</font>
#
#
#
#
# ## <font color="1497d4">  **Accented Speech Recognition - Speech Repo**</font>
#
# <font color=white> **speech recognition @ voize**</font>
#
# ## <font color="1497d4">  **Development Workflow**</font>
#
# <font color=white> **Setup dev environment:**</font>

# %% [markdown]
# ## <font color="1497d4">  **Running a Basic Emformer Training**</font>
#
#
#
#
# ## <font color="1497d4">  **Accented Speech Recognition - Speech Repo**</font>
#
# <font color=white> **speech recognition @ voize**</font>
#
# ## <font color="1497d4">  **Development Workflow**</font>
#
# <font color=white> **Setup dev environment:**</font>

# %% [markdown]
# ##Training efficiency
#
# Measured on common-voice-de 6.1 (based on commit bff9e3f9afcb3893451f4d52ecf811f32c8ff59d):

# %% [markdown]
# Measured on common-voice-de 6.1 concatenated with multilingual-librispeech-de (some data dropped):

# %% [markdown]
#  ## Statistical Analysis for Accented Speech recognition
#  ## Mozilla Common Voice 10.0. dataset download
